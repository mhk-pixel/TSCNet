# %%
# ============================================================================
# EEG Classification Pipeline 
# ============================================================================
import sys
sys.path.append("/teamspace/studios/this_studio/Phd")
from src.tools import tools
from config import config
# ============================================================================
# MAIN EXECUTION
# ============================================================================
def main():
    modules = tools()
    modules.set_seed(seed=modules.config['random_state'])
    modules.print_config()
    modules.setup_output_directory()
    
    try:
        print("\nGet dataset...")
        folds = modules.dataset.data_split(
            k_folds=modules.config['k_folds'], 
            groups=modules.config['groups'],
            fold_type=modules.config['fold_strategy'],
            strategy=modules.config['strategy'],
            val_split=modules.config['val_split'],
            random_state=modules.config['random_state']
        )
        print(f"\nCreated {len(folds)} folds")
        print(f"\n{'='*80}\nStarting {modules.config['k_folds']}-fold cross-validation\n{'='*80}")
        
        all_fold_results = []
        successful_folds = 0
        
        for fold_config in folds:
            modules.set_seed(seed=modules.config['random_state'])
            result = modules.run_single_fold(fold_config)
            if result is not None:
                modules.save_segment_details(result)
                all_fold_results.append(result)
                successful_folds += 1
                print(f"\nCompleted {successful_folds}/{len(folds)} folds")
                
        modules.save_all_fold_details(all_fold_results)
        #=======================================================================
        if all_fold_results:
            modules.print_final_results(all_fold_results)
            modules.save_subject_voting_proportions(all_fold_results)
            print(f"\n{'='*80}\nPIPELINE COMPLETED SUCCESSFULLY!\n{'='*80}")
            print(f"Successful folds: {successful_folds}/{len(folds)}")
            
            #=========================================
            modules.generate_plots_from_saved_results()
            modules.save_segment_csvs_from_results()
            t = modules.save_subject_voting_proportions(all_fold_results)
            modules.report_performance_separately(t)
           
        else:
            print(f"\n{'!'*80}\nPIPELINE FAILED - No folds completed successfully\n{'!'*80}")

    except Exception as e:
        print(f"\n{'!'*80}\nPIPELINE FAILED: {e}\n{'!'*80}")
        traceback.print_exc()
    
    finally:
        modules.clear_memory()
        print("\nMemory cleanup completed")   


if __name__ == "__main__":
    main()
# Out:
# Loading information from: /teamspace/studios/this_studio/phdResearch/data2/Labels/labels.csv
# Contains 67 Subjects
#
# ================================================================================
# EEG CLASSIFICATION PIPELINE
# Mode: Train-Test Split (No Validation)
# ================================================================================
# Configuration:
# --------------------------------------------------------------------------------
#   Dataset path:      /teamspace/studios/this_studio/phdResearch/data2/
#   Device:            cuda
#   Model choice:      0
#   Fold strategy:     manual67
#   Number of folds:   5
#   Validation split:  None
#   Early stopping:    Disabled
#
# Stratification: on (['Group'])
#
# Data Settings:
#   Class names:       ['HC', 'AD']
#   Normalization:     none
#   Norm level:        per_channel
#
# Training Settings:
#   Batch size:        16
#   Learning rate:     1e-06
#   Max epochs:        30
#
# Evaluation Settings:
#   Aggregation mode:  majority
#   Confidence filter: 0.3
#   Save models:       True
# ================================================================================
# Existing experiment directory deleted: /teamspace/studios/this_studio/Phd/experiment/BrainLat/results/brainlatgithub
#
# Output directory setup complete: /teamspace/studios/this_studio/Phd/experiment/BrainLat/results/brainlatgithub
#
# Get dataset...
# Preparing split data..
# Loading ids and labels..
# Preparing manual67 cross-validation with 5 folds
#
# Fold 1:
#   Train: 54 subjects
#   Val:   None
#   Test:  13 subjects
#
# Fold 2:
#   Train: 53 subjects
#   Val:   None
#   Test:  14 subjects
#
# Fold 3:
#   Train: 54 subjects
#   Val:   None
#   Test:  13 subjects
#
# Fold 4:
#   Train: 53 subjects
#   Val:   None
#   Test:  14 subjects
#
# Fold 5:
#   Train: 54 subjects
#   Val:   None
#   Test:  13 subjects
#
# Created 5 folds
#
# ================================================================================
# Starting 5-fold cross-validation
# ================================================================================
#
# ================================================================================
# Processing Fold 1
# ================================================================================
#
# ================================================================================
# Preparing Data for Fold 1
# ================================================================================
#   Segments per subject: All
#   Normalization:        none
#   Norm level:           per_channel
#
# Loading Train data:
# ────────────────────────────────────────────────────────────
# Sub_026:   33 segments (class 1)
# Sub_063:  118 segments (class 0)
# Sub_062:  132 segments (class 0)
# Sub_015:   90 segments (class 1)
# Sub_056:  120 segments (class 0)
# Sub_006:   28 segments (class 1)
# Sub_023:   96 segments (class 1)
# Sub_066:  116 segments (class 0)
# Sub_004:   62 segments (class 1)
# Sub_042:   99 segments (class 0)
# Sub_016:   82 segments (class 1)
# Sub_009:   32 segments (class 1)
# Sub_035:   82 segments (class 1)
# Sub_007:   45 segments (class 1)
# Sub_044:   57 segments (class 0)
# Sub_005:   80 segments (class 1)
# Sub_047:   71 segments (class 0)
# Sub_031:   99 segments (class 1)
# Sub_057:  120 segments (class 0)
# Sub_043:   82 segments (class 0)
# Sub_064:  108 segments (class 0)
# Sub_019:  124 segments (class 1)
# Sub_010:   49 segments (class 1)
# Sub_021:   94 segments (class 1)
# Sub_040:   65 segments (class 0)
# Sub_046:   73 segments (class 0)
# Sub_033:   99 segments (class 1)
# Sub_012:   69 segments (class 1)
# Sub_001:   62 segments (class 1)
# Sub_061:  114 segments (class 0)
# Sub_036:   69 segments (class 0)
# Sub_041:   89 segments (class 0)
# Sub_051:   81 segments (class 0)
# Sub_038:   72 segments (class 0)
# Sub_058:  105 segments (class 0)
# Sub_002:   64 segments (class 1)
# Sub_028:  121 segments (class 1)
# Sub_003:   57 segments (class 1)
# Sub_052:   87 segments (class 0)
# Sub_050:   69 segments (class 0)
# Sub_045:  116 segments (class 0)
# Sub_030:  115 segments (class 1)
# Sub_055:  113 segments (class 0)
# Sub_011:   84 segments (class 1)
# Sub_029:  135 segments (class 1)
# Sub_025:   72 segments (class 1)
# Sub_067:  119 segments (class 0)
# Sub_027:  113 segments (class 1)
# Sub_008:   74 segments (class 1)
# Sub_054:   75 segments (class 0)
# Sub_017:   87 segments (class 1)
# Sub_037:   82 segments (class 0)
# Sub_065:  118 segments (class 0)
# Sub_048:   71 segments (class 0)
#
# Loading Test data:
# ────────────────────────────────────────────────────────────
# Sub_060:  118 segments (class 0)
# Sub_039:   72 segments (class 0)
# Sub_059:  110 segments (class 0)
# Sub_053:   71 segments (class 0)
# Sub_013:   83 segments (class 1)
# Sub_024:  105 segments (class 1)
# Sub_018:  116 segments (class 1)
# Sub_049:   53 segments (class 0)
# Sub_034:  116 segments (class 1)
# Sub_032:  112 segments (class 1)
# Sub_020:  101 segments (class 1)
# Sub_014:   79 segments (class 1)
# Sub_022:  109 segments (class 1)
#
# ================================================================================
# Data Preparation Complete for Fold 1
# ================================================================================
#   Train:       (4689, 19, 640)
#   Validation:  None
#   Test:        (1245, 19, 640)
# ================================================================================
#
#
# Dataset split:
#   Train: 4689 samples
#   Val:   None (val_split=0) samples
#   Test:  1245 samples
#
# Model: EEGModel | Device: cuda
# Total parameters: 490,114 | Trainable: 490,114
#
# Training without validation set (using all epochs)...
#
# ================================================================================
# << TRAINING STARTED >>
# ================================================================================
# Device: cuda | Train samples: 4,689
# Batch size: 16 | Effective batch size: 16
# Max epochs: 30 | Early stopping patience: None
# ================================================================================
#
# Epoch [  1/30] | Train Acc:  85.99% | LR: 1.00e-06
# Epoch [  2/30] | Train Acc:  95.33% | LR: 1.00e-06
# Epoch [  3/30] | Train Acc:  96.84% | LR: 1.00e-06
# Epoch [  4/30] | Train Acc:  97.99% | LR: 1.00e-06
# Epoch [  5/30] | Train Acc:  97.80% | LR: 1.00e-06
# Epoch [  6/30] | Train Acc:  98.55% | LR: 1.00e-06
# Epoch [  7/30] | Train Acc:  98.44% | LR: 1.00e-06
# Epoch [  8/30] | Train Acc:  98.10% | LR: 1.00e-06
# Epoch [  9/30] | Train Acc:  98.34% | LR: 1.00e-06
# Epoch [ 10/30] | Train Acc:  98.68% | LR: 1.00e-06
# Epoch [ 11/30] | Train Acc:  99.04% | LR: 1.00e-06
# Epoch [ 12/30] | Train Acc:  98.98% | LR: 1.00e-06
# Epoch [ 13/30] | Train Acc:  98.98% | LR: 1.00e-06
# Epoch [ 14/30] | Train Acc:  99.04% | LR: 1.00e-06
# Epoch [ 15/30] | Train Acc:  99.27% | LR: 1.00e-06
# Epoch [ 16/30] | Train Acc:  98.87% | LR: 1.00e-06
# Epoch [ 17/30] | Train Acc:  99.25% | LR: 1.00e-06
# Epoch [ 18/30] | Train Acc:  99.30% | LR: 1.00e-06
# Epoch [ 19/30] | Train Acc:  99.17% | LR: 1.00e-06
# Epoch [ 20/30] | Train Acc:  99.13% | LR: 1.00e-06
# Epoch [ 21/30] | Train Acc:  99.17% | LR: 1.00e-06
# Epoch [ 22/30] | Train Acc:  99.15% | LR: 1.00e-06
# Epoch [ 23/30] | Train Acc:  99.27% | LR: 1.00e-06
# Epoch [ 24/30] | Train Acc:  99.25% | LR: 1.00e-06
# Epoch [ 25/30] | Train Acc:  99.17% | LR: 1.00e-06
# Epoch [ 26/30] | Train Acc:  99.36% | LR: 1.00e-06
# Epoch [ 27/30] | Train Acc:  99.47% | LR: 1.00e-06
# Epoch [ 28/30] | Train Acc:  99.55% | LR: 1.00e-06
# Epoch [ 29/30] | Train Acc:  99.40% | LR: 1.00e-06
# Epoch [ 30/30] | Train Acc:  99.42% | LR: 1.00e-06
#
# ================================================================================
# TRAINING COMPLETED | Best Val Acc: 0.00%
# ================================================================================
#
#
# === Subject-level Evaluation (13 subjects) ===
# ==================================================
# === Final Subject-Level Metrics ===
# ==================================================
# Evaluated Subjects: 13/13
# Accuracy:             1.0000
# Sensitivity (AD):    1.0000
# Specificity (HC):    1.0000
# Precision (AD):      1.0000
# F1-Score (AD):       1.0000
# ROC-AUC:             1.0000
# ==================================================
#
# ================================================================================
# Fold 1 Test Results
# ================================================================================
#   Accuracy:    1.0000 (100.00%)
#   Sensitivity: 1.0000 (100.00%)
#   Specificity: 1.0000 (100.00%)
#   ROC AUC:     1.0000
#   Precision:   1.0000
#   Recall:      1.0000
#   F1-Score:    1.0000
# ================================================================================
#
#
# ================================================================================
# Segment CSV Files ...
# ================================================================================
#  Fold 1: files saved successfully.
# ================================================================================
#
# Completed 1/5 folds
#
# ================================================================================
# Processing Fold 2
# ================================================================================
#
# ================================================================================
# Preparing Data for Fold 2
# ================================================================================
#   Segments per subject: All
#   Normalization:        none
#   Norm level:           per_channel
#
# Loading Train data:
# ────────────────────────────────────────────────────────────
# Sub_025:   72 segments (class 1)
# Sub_053:   71 segments (class 0)
# Sub_061:  114 segments (class 0)
# Sub_017:   87 segments (class 1)
# Sub_055:  113 segments (class 0)
# Sub_007:   45 segments (class 1)
# Sub_023:   96 segments (class 1)
# Sub_064:  108 segments (class 0)
# Sub_005:   80 segments (class 1)
# Sub_043:   82 segments (class 0)
# Sub_018:  116 segments (class 1)
# Sub_013:   83 segments (class 1)
# Sub_033:   99 segments (class 1)
# Sub_010:   49 segments (class 1)
# Sub_045:  116 segments (class 0)
# Sub_006:   28 segments (class 1)
# Sub_049:   53 segments (class 0)
# Sub_031:   99 segments (class 1)
# Sub_058:  105 segments (class 0)
# Sub_044:   57 segments (class 0)
# Sub_063:  118 segments (class 0)
# Sub_021:   94 segments (class 1)
# Sub_014:   79 segments (class 1)
# Sub_022:  109 segments (class 1)
# Sub_040:   65 segments (class 0)
# Sub_047:   71 segments (class 0)
# Sub_032:  112 segments (class 1)
# Sub_016:   82 segments (class 1)
# Sub_001:   62 segments (class 1)
# Sub_060:  118 segments (class 0)
# Sub_034:  116 segments (class 1)
# Sub_042:   99 segments (class 0)
# Sub_051:   81 segments (class 0)
# Sub_039:   72 segments (class 0)
# Sub_059:  110 segments (class 0)
# Sub_003:   57 segments (class 1)
# Sub_027:  113 segments (class 1)
# Sub_004:   62 segments (class 1)
# Sub_052:   87 segments (class 0)
# Sub_046:   73 segments (class 0)
# Sub_030:  115 segments (class 1)
# Sub_062:  132 segments (class 0)
# Sub_015:   90 segments (class 1)
# Sub_029:  135 segments (class 1)
# Sub_024:  105 segments (class 1)
# Sub_066:  116 segments (class 0)
# Sub_026:   33 segments (class 1)
# Sub_012:   69 segments (class 1)
# Sub_054:   75 segments (class 0)
# Sub_020:  101 segments (class 1)
# Sub_036:   69 segments (class 0)
# Sub_065:  118 segments (class 0)
# Sub_050:   69 segments (class 0)
#
# Loading Test data:
# ────────────────────────────────────────────────────────────
# Sub_048:   71 segments (class 0)
# Sub_038:   72 segments (class 0)
# Sub_067:  119 segments (class 0)
# Sub_041:   89 segments (class 0)
# Sub_057:  120 segments (class 0)
# Sub_056:  120 segments (class 0)
# Sub_002:   64 segments (class 1)
# Sub_028:  121 segments (class 1)
# Sub_009:   32 segments (class 1)
# Sub_037:   82 segments (class 0)
# Sub_035:   82 segments (class 1)
# Sub_011:   84 segments (class 1)
# Sub_008:   74 segments (class 1)
# Sub_019:  124 segments (class 1)
#
# ================================================================================
# Data Preparation Complete for Fold 2
# ================================================================================
#   Train:       (4680, 19, 640)
#   Validation:  None
#   Test:        (1254, 19, 640)
# ================================================================================
#
#
# Dataset split:
#   Train: 4680 samples
#   Val:   None (val_split=0) samples
#   Test:  1254 samples
#
# Model: EEGModel | Device: cuda
# Total parameters: 490,114 | Trainable: 490,114
#
# Training without validation set (using all epochs)...
#
# ================================================================================
# << TRAINING STARTED >>
# ================================================================================
# Device: cuda | Train samples: 4,680
# Batch size: 16 | Effective batch size: 16
# Max epochs: 30 | Early stopping patience: None
# ================================================================================
#
# Epoch [  1/30] | Train Acc:  83.48% | LR: 1.00e-06
# Epoch [  2/30] | Train Acc:  94.37% | LR: 1.00e-06
# Epoch [  3/30] | Train Acc:  95.46% | LR: 1.00e-06
# Epoch [  4/30] | Train Acc:  97.24% | LR: 1.00e-06
# Epoch [  5/30] | Train Acc:  96.85% | LR: 1.00e-06
# Epoch [  6/30] | Train Acc:  97.65% | LR: 1.00e-06
# Epoch [  7/30] | Train Acc:  97.88% | LR: 1.00e-06
# Epoch [  8/30] | Train Acc:  98.27% | LR: 1.00e-06
# Epoch [  9/30] | Train Acc:  97.84% | LR: 1.00e-06
# Epoch [ 10/30] | Train Acc:  98.12% | LR: 1.00e-06
# Epoch [ 11/30] | Train Acc:  98.24% | LR: 1.00e-06
# Epoch [ 12/30] | Train Acc:  98.54% | LR: 1.00e-06
# Epoch [ 13/30] | Train Acc:  98.29% | LR: 1.00e-06
# Epoch [ 14/30] | Train Acc:  98.39% | LR: 1.00e-06
# Epoch [ 15/30] | Train Acc:  98.35% | LR: 1.00e-06
# Epoch [ 16/30] | Train Acc:  98.50% | LR: 1.00e-06
# Epoch [ 17/30] | Train Acc:  98.39% | LR: 1.00e-06
# Epoch [ 18/30] | Train Acc:  98.69% | LR: 1.00e-06
# Epoch [ 19/30] | Train Acc:  98.31% | LR: 1.00e-06
# Epoch [ 20/30] | Train Acc:  98.80% | LR: 1.00e-06
# Epoch [ 21/30] | Train Acc:  98.74% | LR: 1.00e-06
# Epoch [ 22/30] | Train Acc:  98.91% | LR: 1.00e-06
# Epoch [ 23/30] | Train Acc:  98.65% | LR: 1.00e-06
# Epoch [ 24/30] | Train Acc:  98.87% | LR: 1.00e-06
# Epoch [ 25/30] | Train Acc:  99.02% | LR: 1.00e-06
# Epoch [ 26/30] | Train Acc:  99.02% | LR: 1.00e-06
# Epoch [ 27/30] | Train Acc:  98.50% | LR: 1.00e-06
# Epoch [ 28/30] | Train Acc:  99.04% | LR: 1.00e-06
# Epoch [ 29/30] | Train Acc:  99.08% | LR: 1.00e-06
# Epoch [ 30/30] | Train Acc:  99.08% | LR: 1.00e-06
#
# ================================================================================
# TRAINING COMPLETED | Best Val Acc: 0.00%
# ================================================================================
#
#
# === Subject-level Evaluation (14 subjects) ===
# ==================================================
# === Final Subject-Level Metrics ===
# ==================================================
# Evaluated Subjects: 14/14
# Accuracy:             1.0000
# Sensitivity (AD):    1.0000
# Specificity (HC):    1.0000
# Precision (AD):      1.0000
# F1-Score (AD):       1.0000
# ROC-AUC:             1.0000
# ==================================================
#
# ================================================================================
# Fold 2 Test Results
# ================================================================================
#   Accuracy:    1.0000 (100.00%)
#   Sensitivity: 1.0000 (100.00%)
#   Specificity: 1.0000 (100.00%)
#   ROC AUC:     1.0000
#   Precision:   1.0000
#   Recall:      1.0000
#   F1-Score:    1.0000
# ================================================================================
#
#
# ================================================================================
# Segment CSV Files ...
# ================================================================================
#  Fold 2: files saved successfully.
# ================================================================================
#
# Completed 2/5 folds
#
# ================================================================================
# Processing Fold 3
# ================================================================================
#
# ================================================================================
# Preparing Data for Fold 3
# ================================================================================
#   Segments per subject: All
#   Normalization:        none
#   Norm level:           per_channel
#
# Loading Train data:
# ────────────────────────────────────────────────────────────
# Sub_025:   72 segments (class 1)
# Sub_061:  114 segments (class 0)
# Sub_060:  118 segments (class 0)
# Sub_018:  116 segments (class 1)
# Sub_056:  120 segments (class 0)
# Sub_008:   74 segments (class 1)
# Sub_023:   96 segments (class 1)
# Sub_066:  116 segments (class 0)
# Sub_004:   62 segments (class 1)
# Sub_040:   65 segments (class 0)
# Sub_019:  124 segments (class 1)
# Sub_012:   69 segments (class 1)
# Sub_034:  116 segments (class 1)
# Sub_009:   32 segments (class 1)
# Sub_042:   99 segments (class 0)
# Sub_006:   28 segments (class 1)
# Sub_048:   71 segments (class 0)
# Sub_031:   99 segments (class 1)
# Sub_057:  120 segments (class 0)
# Sub_041:   89 segments (class 0)
# Sub_062:  132 segments (class 0)
# Sub_021:   94 segments (class 1)
# Sub_013:   83 segments (class 1)
# Sub_022:  109 segments (class 1)
# Sub_038:   72 segments (class 0)
# Sub_046:   73 segments (class 0)
# Sub_032:  112 segments (class 1)
# Sub_016:   82 segments (class 1)
# Sub_001:   62 segments (class 1)
# Sub_059:  110 segments (class 0)
# Sub_035:   82 segments (class 1)
# Sub_039:   72 segments (class 0)
# Sub_052:   87 segments (class 0)
# Sub_037:   82 segments (class 0)
# Sub_058:  105 segments (class 0)
# Sub_002:   64 segments (class 1)
# Sub_027:  113 segments (class 1)
# Sub_003:   57 segments (class 1)
# Sub_053:   71 segments (class 0)
# Sub_051:   81 segments (class 0)
# Sub_045:  116 segments (class 0)
# Sub_029:  135 segments (class 1)
# Sub_055:  113 segments (class 0)
# Sub_014:   79 segments (class 1)
# Sub_028:  121 segments (class 1)
# Sub_024:  105 segments (class 1)
# Sub_067:  119 segments (class 0)
# Sub_026:   33 segments (class 1)
# Sub_011:   84 segments (class 1)
# Sub_054:   75 segments (class 0)
# Sub_020:  101 segments (class 1)
# Sub_036:   69 segments (class 0)
# Sub_064:  108 segments (class 0)
# Sub_049:   53 segments (class 0)
#
# Loading Test data:
# ────────────────────────────────────────────────────────────
# Sub_065:  118 segments (class 0)
# Sub_044:   57 segments (class 0)
# Sub_063:  118 segments (class 0)
# Sub_050:   69 segments (class 0)
# Sub_005:   80 segments (class 1)
# Sub_030:  115 segments (class 1)
# Sub_010:   49 segments (class 1)
# Sub_047:   71 segments (class 0)
# Sub_043:   82 segments (class 0)
# Sub_033:   99 segments (class 1)
# Sub_015:   90 segments (class 1)
# Sub_007:   45 segments (class 1)
# Sub_017:   87 segments (class 1)
#
# ================================================================================
# Data Preparation Complete for Fold 3
# ================================================================================
#   Train:       (4854, 19, 640)
#   Validation:  None
#   Test:        (1080, 19, 640)
# ================================================================================
#
#
# Dataset split:
#   Train: 4854 samples
#   Val:   None (val_split=0) samples
#   Test:  1080 samples
#
# Model: EEGModel | Device: cuda
# Total parameters: 490,114 | Trainable: 490,114
#
# Training without validation set (using all epochs)...
#
# ================================================================================
# << TRAINING STARTED >>
# ================================================================================
# Device: cuda | Train samples: 4,854
# Batch size: 16 | Effective batch size: 16
# Max epochs: 30 | Early stopping patience: None
# ================================================================================
#
# Epoch [  1/30] | Train Acc:  85.48% | LR: 1.00e-06
# Epoch [  2/30] | Train Acc:  95.79% | LR: 1.00e-06
# Epoch [  3/30] | Train Acc:  96.62% | LR: 1.00e-06
# Epoch [  4/30] | Train Acc:  97.07% | LR: 1.00e-06
# Epoch [  5/30] | Train Acc:  96.99% | LR: 1.00e-06
# Epoch [  6/30] | Train Acc:  98.08% | LR: 1.00e-06
# Epoch [  7/30] | Train Acc:  98.21% | LR: 1.00e-06
# Epoch [  8/30] | Train Acc:  98.41% | LR: 1.00e-06
# Epoch [  9/30] | Train Acc:  98.37% | LR: 1.00e-06
# Epoch [ 10/30] | Train Acc:  98.68% | LR: 1.00e-06
# Epoch [ 11/30] | Train Acc:  98.37% | LR: 1.00e-06
# Epoch [ 12/30] | Train Acc:  98.62% | LR: 1.00e-06
# Epoch [ 13/30] | Train Acc:  98.31% | LR: 1.00e-06
# Epoch [ 14/30] | Train Acc:  98.78% | LR: 1.00e-06
# Epoch [ 15/30] | Train Acc:  98.68% | LR: 1.00e-06
# Epoch [ 16/30] | Train Acc:  99.03% | LR: 1.00e-06
# Epoch [ 17/30] | Train Acc:  98.89% | LR: 1.00e-06
# Epoch [ 18/30] | Train Acc:  98.78% | LR: 1.00e-06
# Epoch [ 19/30] | Train Acc:  99.20% | LR: 1.00e-06
# Epoch [ 20/30] | Train Acc:  99.17% | LR: 1.00e-06
# Epoch [ 21/30] | Train Acc:  98.84% | LR: 1.00e-06
# Epoch [ 22/30] | Train Acc:  98.74% | LR: 1.00e-06
# Epoch [ 23/30] | Train Acc:  98.87% | LR: 1.00e-06
# Epoch [ 24/30] | Train Acc:  98.78% | LR: 1.00e-06
# Epoch [ 25/30] | Train Acc:  99.30% | LR: 1.00e-06
# Epoch [ 26/30] | Train Acc:  99.09% | LR: 1.00e-06
# Epoch [ 27/30] | Train Acc:  99.17% | LR: 1.00e-06
# Epoch [ 28/30] | Train Acc:  99.03% | LR: 1.00e-06
# Epoch [ 29/30] | Train Acc:  99.09% | LR: 1.00e-06
# Epoch [ 30/30] | Train Acc:  99.38% | LR: 1.00e-06
#
# ================================================================================
# TRAINING COMPLETED | Best Val Acc: 0.00%
# ================================================================================
#
#
# === Subject-level Evaluation (13 subjects) ===
# ==================================================
# === Final Subject-Level Metrics ===
# ==================================================
# Evaluated Subjects: 13/13
# Accuracy:             1.0000
# Sensitivity (AD):    1.0000
# Specificity (HC):    1.0000
# Precision (AD):      1.0000
# F1-Score (AD):       1.0000
# ROC-AUC:             1.0000
# ==================================================
#
# ================================================================================
# Fold 3 Test Results
# ================================================================================
#   Accuracy:    1.0000 (100.00%)
#   Sensitivity: 1.0000 (100.00%)
#   Specificity: 1.0000 (100.00%)
#   ROC AUC:     1.0000
#   Precision:   1.0000
#   Recall:      1.0000
#   F1-Score:    1.0000
# ================================================================================
#
#
# ================================================================================
# Segment CSV Files ...
# ================================================================================
#  Fold 3: files saved successfully.
# ================================================================================
#
# Completed 3/5 folds
#
# ================================================================================
# Processing Fold 4
# ================================================================================
#
# ================================================================================
# Preparing Data for Fold 4
# ================================================================================
#   Segments per subject: All
#   Normalization:        none
#   Norm level:           per_channel
#
# Loading Train data:
# ────────────────────────────────────────────────────────────
# Sub_022:  109 segments (class 1)
# Sub_050:   69 segments (class 0)
# Sub_058:  105 segments (class 0)
# Sub_014:   79 segments (class 1)
# Sub_052:   87 segments (class 0)
# Sub_007:   45 segments (class 1)
# Sub_019:  124 segments (class 1)
# Sub_063:  118 segments (class 0)
# Sub_005:   80 segments (class 1)
# Sub_040:   65 segments (class 0)
# Sub_015:   90 segments (class 1)
# Sub_010:   49 segments (class 1)
# Sub_033:   99 segments (class 1)
# Sub_008:   74 segments (class 1)
# Sub_043:   82 segments (class 0)
# Sub_006:   28 segments (class 1)
# Sub_046:   73 segments (class 0)
# Sub_030:  115 segments (class 1)
# Sub_053:   71 segments (class 0)
# Sub_041:   89 segments (class 0)
# Sub_060:  118 segments (class 0)
# Sub_017:   87 segments (class 1)
# Sub_011:   84 segments (class 1)
# Sub_018:  116 segments (class 1)
# Sub_038:   72 segments (class 0)
# Sub_045:  116 segments (class 0)
# Sub_032:  112 segments (class 1)
# Sub_013:   83 segments (class 1)
# Sub_001:   62 segments (class 1)
# Sub_057:  120 segments (class 0)
# Sub_034:  116 segments (class 1)
# Sub_039:   72 segments (class 0)
# Sub_048:   71 segments (class 0)
# Sub_037:   82 segments (class 0)
# Sub_056:  120 segments (class 0)
# Sub_002:   64 segments (class 1)
# Sub_024:  105 segments (class 1)
# Sub_004:   62 segments (class 1)
# Sub_049:   53 segments (class 0)
# Sub_044:   57 segments (class 0)
# Sub_028:  121 segments (class 1)
# Sub_059:  110 segments (class 0)
# Sub_012:   69 segments (class 1)
# Sub_025:   72 segments (class 1)
# Sub_020:  101 segments (class 1)
# Sub_067:  119 segments (class 0)
# Sub_023:   96 segments (class 1)
# Sub_009:   32 segments (class 1)
# Sub_051:   81 segments (class 0)
# Sub_016:   82 segments (class 1)
# Sub_035:   82 segments (class 1)
# Sub_065:  118 segments (class 0)
# Sub_047:   71 segments (class 0)
#
# Loading Test data:
# ────────────────────────────────────────────────────────────
# Sub_061:  114 segments (class 0)
# Sub_054:   75 segments (class 0)
# Sub_066:  116 segments (class 0)
# Sub_055:  113 segments (class 0)
# Sub_064:  108 segments (class 0)
# Sub_062:  132 segments (class 0)
# Sub_003:   57 segments (class 1)
# Sub_031:   99 segments (class 1)
# Sub_026:   33 segments (class 1)
# Sub_042:   99 segments (class 0)
# Sub_036:   69 segments (class 0)
# Sub_027:  113 segments (class 1)
# Sub_021:   94 segments (class 1)
# Sub_029:  135 segments (class 1)
#
# ================================================================================
# Data Preparation Complete for Fold 4
# ================================================================================
#   Train:       (4577, 19, 640)
#   Validation:  None
#   Test:        (1357, 19, 640)
# ================================================================================
#
#
# Dataset split:
#   Train: 4577 samples
#   Val:   None (val_split=0) samples
#   Test:  1357 samples
#
# Model: EEGModel | Device: cuda
# Total parameters: 490,114 | Trainable: 490,114
#
# Training without validation set (using all epochs)...
#
# ================================================================================
# << TRAINING STARTED >>
# ================================================================================
# Device: cuda | Train samples: 4,577
# Batch size: 16 | Effective batch size: 16
# Max epochs: 30 | Early stopping patience: None
# ================================================================================
#
# Epoch [  1/30] | Train Acc:  84.44% | LR: 1.00e-06
# Epoch [  2/30] | Train Acc:  94.60% | LR: 1.00e-06
# Epoch [  3/30] | Train Acc:  95.48% | LR: 1.00e-06
# Epoch [  4/30] | Train Acc:  97.03% | LR: 1.00e-06
# Epoch [  5/30] | Train Acc:  97.71% | LR: 1.00e-06
# Epoch [  6/30] | Train Acc:  97.84% | LR: 1.00e-06
# Epoch [  7/30] | Train Acc:  98.21% | LR: 1.00e-06
# Epoch [  8/30] | Train Acc:  98.16% | LR: 1.00e-06
# Epoch [  9/30] | Train Acc:  98.60% | LR: 1.00e-06
# Epoch [ 10/30] | Train Acc:  98.27% | LR: 1.00e-06
# Epoch [ 11/30] | Train Acc:  98.65% | LR: 1.00e-06
# Epoch [ 12/30] | Train Acc:  98.75% | LR: 1.00e-06
# Epoch [ 13/30] | Train Acc:  98.38% | LR: 1.00e-06
# Epoch [ 14/30] | Train Acc:  98.78% | LR: 1.00e-06
# Epoch [ 15/30] | Train Acc:  98.97% | LR: 1.00e-06
# Epoch [ 16/30] | Train Acc:  98.89% | LR: 1.00e-06
# Epoch [ 17/30] | Train Acc:  98.99% | LR: 1.00e-06
# Epoch [ 18/30] | Train Acc:  99.13% | LR: 1.00e-06
# Epoch [ 19/30] | Train Acc:  99.34% | LR: 1.00e-06
# Epoch [ 20/30] | Train Acc:  99.17% | LR: 1.00e-06
# Epoch [ 21/30] | Train Acc:  99.26% | LR: 1.00e-06
# Epoch [ 22/30] | Train Acc:  98.84% | LR: 1.00e-06
# Epoch [ 23/30] | Train Acc:  99.10% | LR: 1.00e-06
# Epoch [ 24/30] | Train Acc:  99.06% | LR: 1.00e-06
# Epoch [ 25/30] | Train Acc:  99.06% | LR: 1.00e-06
# Epoch [ 26/30] | Train Acc:  98.95% | LR: 1.00e-06
# Epoch [ 27/30] | Train Acc:  99.10% | LR: 1.00e-06
# Epoch [ 28/30] | Train Acc:  99.21% | LR: 1.00e-06
# Epoch [ 29/30] | Train Acc:  99.43% | LR: 1.00e-06
# Epoch [ 30/30] | Train Acc:  99.30% | LR: 1.00e-06
#
# ================================================================================
# TRAINING COMPLETED | Best Val Acc: 0.00%
# ================================================================================
#
#
# === Subject-level Evaluation (14 subjects) ===
# ==================================================
# === Final Subject-Level Metrics ===
# ==================================================
# Evaluated Subjects: 14/14
# Accuracy:             0.9286
# Sensitivity (AD):    0.8333
# Specificity (HC):    1.0000
# Precision (AD):      1.0000
# F1-Score (AD):       0.9091
# ROC-AUC:             1.0000
# ==================================================
#
# ================================================================================
# Fold 4 Test Results
# ================================================================================
#   Accuracy:    0.9286 (92.86%)
#   Sensitivity: 0.8333 (83.33%)
#   Specificity: 1.0000 (100.00%)
#   ROC AUC:     1.0000
#   Precision:   1.0000
#   Recall:      0.8333
#   F1-Score:    0.9091
# ================================================================================
#
#
# ================================================================================
# Segment CSV Files ...
# ================================================================================
#  Fold 4: files saved successfully.
# ================================================================================
#
# Completed 4/5 folds
#
# ================================================================================
# Processing Fold 5
# ================================================================================
#
# ================================================================================
# Preparing Data for Fold 5
# ================================================================================
#   Segments per subject: All
#   Normalization:        none
#   Norm level:           per_channel
#
# Loading Train data:
# ────────────────────────────────────────────────────────────
# Sub_027:  113 segments (class 1)
# Sub_063:  118 segments (class 0)
# Sub_062:  132 segments (class 0)
# Sub_018:  116 segments (class 1)
# Sub_057:  120 segments (class 0)
# Sub_009:   32 segments (class 1)
# Sub_024:  105 segments (class 1)
# Sub_066:  116 segments (class 0)
# Sub_007:   45 segments (class 1)
# Sub_041:   89 segments (class 0)
# Sub_019:  124 segments (class 1)
# Sub_013:   83 segments (class 1)
# Sub_034:  116 segments (class 1)
# Sub_010:   49 segments (class 1)
# Sub_043:   82 segments (class 0)
# Sub_008:   74 segments (class 1)
# Sub_048:   71 segments (class 0)
# Sub_032:  112 segments (class 1)
# Sub_059:  110 segments (class 0)
# Sub_042:   99 segments (class 0)
# Sub_064:  108 segments (class 0)
# Sub_021:   94 segments (class 1)
# Sub_014:   79 segments (class 1)
# Sub_022:  109 segments (class 1)
# Sub_038:   72 segments (class 0)
# Sub_047:   71 segments (class 0)
# Sub_033:   99 segments (class 1)
# Sub_017:   87 segments (class 1)
# Sub_002:   64 segments (class 1)
# Sub_061:  114 segments (class 0)
# Sub_035:   82 segments (class 1)
# Sub_039:   72 segments (class 0)
# Sub_053:   71 segments (class 0)
# Sub_037:   82 segments (class 0)
# Sub_060:  118 segments (class 0)
# Sub_003:   57 segments (class 1)
# Sub_029:  135 segments (class 1)
# Sub_005:   80 segments (class 1)
# Sub_054:   75 segments (class 0)
# Sub_050:   69 segments (class 0)
# Sub_044:   57 segments (class 0)
# Sub_031:   99 segments (class 1)
# Sub_056:  120 segments (class 0)
# Sub_015:   90 segments (class 1)
# Sub_030:  115 segments (class 1)
# Sub_026:   33 segments (class 1)
# Sub_067:  119 segments (class 0)
# Sub_028:  121 segments (class 1)
# Sub_011:   84 segments (class 1)
# Sub_055:  113 segments (class 0)
# Sub_020:  101 segments (class 1)
# Sub_036:   69 segments (class 0)
# Sub_065:  118 segments (class 0)
# Sub_049:   53 segments (class 0)
#
# Loading Test data:
# ────────────────────────────────────────────────────────────
# Sub_058:  105 segments (class 0)
# Sub_045:  116 segments (class 0)
# Sub_052:   87 segments (class 0)
# Sub_051:   81 segments (class 0)
# Sub_001:   62 segments (class 1)
# Sub_023:   96 segments (class 1)
# Sub_006:   28 segments (class 1)
# Sub_046:   73 segments (class 0)
# Sub_040:   65 segments (class 0)
# Sub_025:   72 segments (class 1)
# Sub_012:   69 segments (class 1)
# Sub_004:   62 segments (class 1)
# Sub_016:   82 segments (class 1)
#
# ================================================================================
# Data Preparation Complete for Fold 5
# ================================================================================
#   Train:       (4936, 19, 640)
#   Validation:  None
#   Test:        (998, 19, 640)
# ================================================================================
#
#
# Dataset split:
#   Train: 4936 samples
#   Val:   None (val_split=0) samples
#   Test:  998 samples
#
# Model: EEGModel | Device: cuda
# Total parameters: 490,114 | Trainable: 490,114
#
# Training without validation set (using all epochs)...
#
# ================================================================================
# << TRAINING STARTED >>
# ================================================================================
# Device: cuda | Train samples: 4,936
# Batch size: 16 | Effective batch size: 16
# Max epochs: 30 | Early stopping patience: None
# ================================================================================
#
# Epoch [  1/30] | Train Acc:  84.48% | LR: 1.00e-06
# Epoch [  2/30] | Train Acc:  94.16% | LR: 1.00e-06
# Epoch [  3/30] | Train Acc:  95.80% | LR: 1.00e-06
# Epoch [  4/30] | Train Acc:  96.29% | LR: 1.00e-06
# Epoch [  5/30] | Train Acc:  96.79% | LR: 1.00e-06
# Epoch [  6/30] | Train Acc:  97.22% | LR: 1.00e-06
# Epoch [  7/30] | Train Acc:  97.50% | LR: 1.00e-06
# Epoch [  8/30] | Train Acc:  97.97% | LR: 1.00e-06
# Epoch [  9/30] | Train Acc:  98.05% | LR: 1.00e-06
# Epoch [ 10/30] | Train Acc:  98.01% | LR: 1.00e-06
# Epoch [ 11/30] | Train Acc:  97.87% | LR: 1.00e-06
# Epoch [ 12/30] | Train Acc:  98.58% | LR: 1.00e-06
# Epoch [ 13/30] | Train Acc:  98.58% | LR: 1.00e-06
# Epoch [ 14/30] | Train Acc:  98.46% | LR: 1.00e-06
# Epoch [ 15/30] | Train Acc:  98.66% | LR: 1.00e-06
# Epoch [ 16/30] | Train Acc:  98.60% | LR: 1.00e-06
# Epoch [ 17/30] | Train Acc:  98.44% | LR: 1.00e-06
# Epoch [ 18/30] | Train Acc:  98.72% | LR: 1.00e-06
# Epoch [ 19/30] | Train Acc:  98.74% | LR: 1.00e-06
# Epoch [ 20/30] | Train Acc:  98.80% | LR: 1.00e-06
# Epoch [ 21/30] | Train Acc:  98.74% | LR: 1.00e-06
# Epoch [ 22/30] | Train Acc:  99.23% | LR: 1.00e-06
# Epoch [ 23/30] | Train Acc:  98.70% | LR: 1.00e-06
# Epoch [ 24/30] | Train Acc:  98.80% | LR: 1.00e-06
# Epoch [ 25/30] | Train Acc:  98.99% | LR: 1.00e-06
# Epoch [ 26/30] | Train Acc:  99.07% | LR: 1.00e-06
# Epoch [ 27/30] | Train Acc:  99.05% | LR: 1.00e-06
# Epoch [ 28/30] | Train Acc:  99.13% | LR: 1.00e-06
# Epoch [ 29/30] | Train Acc:  99.23% | LR: 1.00e-06
# Epoch [ 30/30] | Train Acc:  98.99% | LR: 1.00e-06
#
# ================================================================================
# TRAINING COMPLETED | Best Val Acc: 0.00%
# ================================================================================
#
#
# === Subject-level Evaluation (13 subjects) ===
# ==================================================
# === Final Subject-Level Metrics ===
# ==================================================
# Evaluated Subjects: 13/13
# Accuracy:             1.0000
# Sensitivity (AD):    1.0000
# Specificity (HC):    1.0000
# Precision (AD):      1.0000
# F1-Score (AD):       1.0000
# ROC-AUC:             1.0000
# ==================================================
#
# ================================================================================
# Fold 5 Test Results
# ================================================================================
#   Accuracy:    1.0000 (100.00%)
#   Sensitivity: 1.0000 (100.00%)
#   Specificity: 1.0000 (100.00%)
#   ROC AUC:     1.0000
#   Precision:   1.0000
#   Recall:      1.0000
#   F1-Score:    1.0000
# ================================================================================
#
#
# ================================================================================
# Segment CSV Files ...
# ================================================================================
#  Fold 5: files saved successfully.
# ================================================================================
#
# Completed 5/5 folds
#
# Complete raw results object saved to: /teamspace/studios/this_studio/Phd/experiment/BrainLat/results/brainlatgithub/tables/raw_all_fold_results.pkl
#
# ================================================================================
# FINAL CROSS-VALIDATION RESULTS
# ================================================================================
#
# Performance Summary (Mean ± Std):
# --------------------------------------------------------------------------------
#   Accuracy       : 0.9857 ± 0.0319 [0.9286, 1.0000]
#   Roc Auc        : 1.0000 ± 0.0000 [1.0000, 1.0000]
#   Sensitivity    : 0.9667 ± 0.0745 [0.8333, 1.0000]
#   Specificity    : 1.0000 ± 0.0000 [1.0000, 1.0000]
#   Precision      : 1.0000 ± 0.0000 [1.0000, 1.0000]
#   Recall         : 0.9667 ± 0.0745 [0.8333, 1.0000]
#   F1 Score       : 0.9818 ± 0.0407 [0.9091, 1.0000]
#
# ================================================================================
# Individual Fold Results
# ================================================================================
#   Fold | Accuracy |       F1 |      AUC |     Sens |     Spec
# --------------------------------------------------------------------------------
#      1 |   1.0000 |   1.0000 |   1.0000 |   1.0000 |   1.0000
#      2 |   1.0000 |   1.0000 |   1.0000 |   1.0000 |   1.0000
#      3 |   1.0000 |   1.0000 |   1.0000 |   1.0000 |   1.0000
#      4 |   0.9286 |   0.9091 |   1.0000 |   0.8333 |   1.0000
#      5 |   1.0000 |   1.0000 |   1.0000 |   1.0000 |   1.0000
# ================================================================================
#
# Results saved to: /teamspace/studios/this_studio/Phd/experiment/BrainLat/results/brainlatgithub/tables/cv_results_manual67_5folds.csv
#
# 95% Confidence Intervals:
# --------------------------------------------------------------------------------
#   Accuracy       : 0.9857 [0.9577, 1.0000]
#   Roc Auc        : 1.0000 [1.0000, 1.0000]
#   Sensitivity    : 0.9667 [0.9013, 1.0000]
#   Specificity    : 1.0000 [1.0000, 1.0000]
#   Precision      : 1.0000 [1.0000, 1.0000]
#   Recall         : 0.9667 [0.9013, 1.0000]
#   F1 Score       : 0.9818 [0.9462, 1.0000]
# ================================================================================
# Confidence intervals saved to: /teamspace/studios/this_studio/Phd/experiment/BrainLat/results/brainlatgithub/tables/confidence_intervals.csv
#
# Full model config, parameters & best fold metrics successfully saved to: /teamspace/studios/this_studio/Phd/experiment/BrainLat/results/brainlatgithub/model_info.json
#
#  Subject-level voting proportions successfully saved to: /teamspace/studios/this_studio/Phd/experiment/BrainLat/results/brainlatgithub/tables/subject_level_voting_proportions.csv
#
# ================================================================================
# PIPELINE COMPLETED SUCCESSFULLY!
# ================================================================================
# Successful folds: 5/5
#
# ================================================================================
# Generating Plots From Saved Results: /teamspace/studios/this_studio/Phd/experiment/BrainLat/results/brainlatgithub/tables/raw_all_fold_results.pkl
# ================================================================================
# Training curves saved: /teamspace/studios/this_studio/Phd/experiment/BrainLat/results/brainlatgithub/plots/fold_1_training_curves.png
# Confusion matrix saved: /teamspace/studios/this_studio/Phd/experiment/BrainLat/results/brainlatgithub/plots/fold_1_confusion_matrix.png
# Training curves saved: /teamspace/studios/this_studio/Phd/experiment/BrainLat/results/brainlatgithub/plots/fold_2_training_curves.png
# Confusion matrix saved: /teamspace/studios/this_studio/Phd/experiment/BrainLat/results/brainlatgithub/plots/fold_2_confusion_matrix.png
# Training curves saved: /teamspace/studios/this_studio/Phd/experiment/BrainLat/results/brainlatgithub/plots/fold_3_training_curves.png
# Confusion matrix saved: /teamspace/studios/this_studio/Phd/experiment/BrainLat/results/brainlatgithub/plots/fold_3_confusion_matrix.png
# Training curves saved: /teamspace/studios/this_studio/Phd/experiment/BrainLat/results/brainlatgithub/plots/fold_4_training_curves.png
# Confusion matrix saved: /teamspace/studios/this_studio/Phd/experiment/BrainLat/results/brainlatgithub/plots/fold_4_confusion_matrix.png
# Training curves saved: /teamspace/studios/this_studio/Phd/experiment/BrainLat/results/brainlatgithub/plots/fold_5_training_curves.png
# Confusion matrix saved: /teamspace/studios/this_studio/Phd/experiment/BrainLat/results/brainlatgithub/plots/fold_5_confusion_matrix.png
#
# ================================================================================
# Cross-Validation Summary
# ================================================================================
#   Accuracy:     0.9857 ± 0.0286
#   AUC:          1.0000 ± 0.0000
#   Sensitivity:  0.9667 ± 0.0667
#   Specificity:  1.0000 ± 0.0000
#   F1-Score:     0.9818 ± 0.0364
# ================================================================================
#
# Mean confusion matrix saved: /teamspace/studios/this_studio/Phd/experiment/BrainLat/results/brainlatgithub/plots/mean_confusion_matrix.png
# ROC curve saved: /teamspace/studios/this_studio/Phd/experiment/BrainLat/results/brainlatgithub/plots/roc_publication.png
# Combined confusion matrices saved successfully: /teamspace/studios/this_studio/Phd/experiment/BrainLat/results/brainlatgithub/plots/combined_confusion_matrices.png
#
# All plots generated successfully and saved in: /teamspace/studios/this_studio/Phd/experiment/BrainLat/results/brainlatgithub/plots
#
# ================================================================================
# Generating Segment CSV Files for All Folds...
# ================================================================================
#
# ================================================================================
# Segment CSV Files ...
# ================================================================================
#  Fold 1: files saved successfully.
# ================================================================================
#
# ================================================================================
# Segment CSV Files ...
# ================================================================================
#  Fold 2: files saved successfully.
# ================================================================================
#
# ================================================================================
# Segment CSV Files ...
# ================================================================================
#  Fold 3: files saved successfully.
# ================================================================================
#
# ================================================================================
# Segment CSV Files ...
# ================================================================================
#  Fold 4: files saved successfully.
# ================================================================================
#
# ================================================================================
# Segment CSV Files ...
# ================================================================================
#  Fold 5: files saved successfully.
# ================================================================================
# ================================================================================
#
#  Subject-level voting proportions successfully saved to: /teamspace/studios/this_studio/Phd/experiment/BrainLat/results/brainlatgithub/tables/subject_level_voting_proportions.csv
# Stratified performance report saved successfully to: /teamspace/studios/this_studio/Phd/experiment/BrainLat/results/brainlatgithub/tables/report_performance_separately.csv
#
# Memory cleanup completed
