# %%
# ============================================================================
# EEG Classification Pipeline 
# ============================================================================
import sys
sys.path.append("/teamspace/studios/this_studio/Phd")
from src.tools import tools
from config import config
# ============================================================================
# MAIN EXECUTION
# ============================================================================
def main():
    modules = tools()
    modules.set_seed(seed=modules.config['random_state'])
    modules.print_config()
    modules.setup_output_directory()
    
    try:
        print("\nGet dataset...")
        folds = modules.dataset.data_split(
            k_folds=modules.config['k_folds'], 
            groups=modules.config['groups'],
            fold_type=modules.config['fold_strategy'],
            strategy=modules.config['strategy'],
            val_split=modules.config['val_split'],
            random_state=modules.config['random_state']
        )
        print(f"\nCreated {len(folds)} folds")
        print(f"\n{'='*80}\nStarting {modules.config['k_folds']}-fold cross-validation\n{'='*80}")
        
        all_fold_results = []
        successful_folds = 0
        
        for fold_config in folds:
            modules.set_seed(seed=modules.config['random_state'])
            result = modules.run_single_fold(fold_config)
            if result is not None:
                modules.save_segment_details(result)
                all_fold_results.append(result)
                successful_folds += 1
                print(f"\nCompleted {successful_folds}/{len(folds)} folds")
                
        modules.save_all_fold_details(all_fold_results)
        #=======================================================================
        if all_fold_results:
            modules.print_final_results(all_fold_results)
            modules.save_subject_voting_proportions(all_fold_results)
            print(f"\n{'='*80}\nPIPELINE COMPLETED SUCCESSFULLY!\n{'='*80}")
            print(f"Successful folds: {successful_folds}/{len(folds)}")
            
            #=========================================
            modules.generate_plots_from_saved_results()
            modules.save_segment_csvs_from_results()
            t = modules.save_subject_voting_proportions(all_fold_results)
            modules.report_performance_separately(t)
            
        else:
            print(f"\n{'!'*80}\nPIPELINE FAILED - No folds completed successfully\n{'!'*80}")

    except Exception as e:
        print(f"\n{'!'*80}\nPIPELINE FAILED: {e}\n{'!'*80}")
        traceback.print_exc()
    
    finally:
        modules.clear_memory()
        print("\nMemory cleanup completed")   


if __name__ == "__main__":
    main()
# Out:
# Loading information from: /teamspace/studios/this_studio/phdResearch/data12/Labels/labels.csv
# Contains 132 Subjects
#
# ================================================================================
# EEG CLASSIFICATION PIPELINE
# Mode: Train-Test Split (No Validation)
# ================================================================================
# Configuration:
# --------------------------------------------------------------------------------
#   Dataset path:      /teamspace/studios/this_studio/phdResearch/data12/
#   Device:            cuda
#   Model choice:      3
#   Fold strategy:     manual132
#   Number of folds:   5
#   Validation split:  None
#   Early stopping:    Disabled
#
# Stratification: on (['Group'])
#
# Data Settings:
#   Class names:       ['HC', 'AD']
#   Normalization:     winsor_zscore
#   Norm level:        per_channel
#
# Training Settings:
#   Batch size:        16
#   Learning rate:     0.0001
#   Max epochs:        30
#
# Evaluation Settings:
#   Aggregation mode:  majority
#   Confidence filter: 0.7
#   Save models:       True
# ================================================================================
#
# Output directory setup complete: /teamspace/studios/this_studio/Phd/experiment/Combined/results/ApplaitionM3
#
# Get dataset...
# Preparing split data..
# Loading ids and labels..
# Preparing manual132 cross-validation with 5 folds
#
# Fold 1:
#   Train: 106 subjects
#   Val:   None
#   Test:  26 subjects
#
# Fold 2:
#   Train: 106 subjects
#   Val:   None
#   Test:  26 subjects
#
# Fold 3:
#   Train: 105 subjects
#   Val:   None
#   Test:  27 subjects
#
# Fold 4:
#   Train: 106 subjects
#   Val:   None
#   Test:  26 subjects
#
# Fold 5:
#   Train: 105 subjects
#   Val:   None
#   Test:  27 subjects
#
# Created 5 folds
#
# ================================================================================
# Starting 5-fold cross-validation
# ================================================================================
#
# ================================================================================
# Processing Fold 1
# ================================================================================
#
# ================================================================================
# Preparing Data for Fold 1
# ================================================================================
#   Segments per subject: All
#   Normalization:        winsor_zscore
#   Norm level:           per_channel
#
# Loading Train data:
# ────────────────────────────────────────────────────────────
# Sub_125:  118 segments (class 0)
# Sub_015:  182 segments (class 1)
# Sub_008:  159 segments (class 1)
# Sub_102:   82 segments (class 0)
# Sub_121:  120 segments (class 0)
# Sub_081:   82 segments (class 1)
# Sub_038:  178 segments (class 0)
# Sub_042:  195 segments (class 0)
# Sub_117:   87 segments (class 0)
# Sub_017:  169 segments (class 1)
# Sub_061:  161 segments (class 0)
# Sub_055:  164 segments (class 0)
# Sub_002:  158 segments (class 1)
# Sub_098:   99 segments (class 1)
# Sub_026:  183 segments (class 1)
# Sub_080:   90 segments (class 1)
# Sub_083:  116 segments (class 1)
# Sub_099:  116 segments (class 1)
# Sub_069:   62 segments (class 1)
# Sub_057:  159 segments (class 0)
# Sub_018:  169 segments (class 1)
# Sub_101:   69 segments (class 0)
# Sub_078:   83 segments (class 1)
# Sub_034:  194 segments (class 1)
# Sub_030:  111 segments (class 1)
# Sub_039:  171 segments (class 0)
# Sub_059:  157 segments (class 0)
# Sub_092:  113 segments (class 1)
# Sub_021:  184 segments (class 1)
# Sub_096:   99 segments (class 1)
# Sub_047:  161 segments (class 0)
# Sub_111:   73 segments (class 0)
# Sub_014:  189 segments (class 1)
# Sub_067:   64 segments (class 1)
# Sub_119:   75 segments (class 0)
# Sub_036:  170 segments (class 1)
# Sub_053:  159 segments (class 0)
# Sub_009:  122 segments (class 1)
# Sub_129:  108 segments (class 0)
# Sub_095:  115 segments (class 1)
# Sub_050:  165 segments (class 0)
# Sub_044:  176 segments (class 0)
# Sub_022:  164 segments (class 1)
# Sub_070:   80 segments (class 1)
# Sub_043:  165 segments (class 0)
# Sub_011:  154 segments (class 1)
# Sub_056:  177 segments (class 0)
# Sub_082:   87 segments (class 1)
# Sub_087:  109 segments (class 1)
# Sub_035:  151 segments (class 1)
# Sub_027:  166 segments (class 1)
# Sub_106:   89 segments (class 0)
# Sub_113:   71 segments (class 0)
# Sub_033:  141 segments (class 1)
# Sub_085:  101 segments (class 1)
# Sub_063:  161 segments (class 0)
# Sub_019:  184 segments (class 1)
# Sub_032:  170 segments (class 1)
# Sub_007:  153 segments (class 1)
# Sub_024:  153 segments (class 1)
# Sub_049:  156 segments (class 0)
# Sub_013:  168 segments (class 1)
# Sub_123:  105 segments (class 0)
# Sub_010:  258 segments (class 1)
# Sub_084:  124 segments (class 1)
# Sub_128:  118 segments (class 0)
# Sub_105:   65 segments (class 0)
# Sub_068:   57 segments (class 1)
# Sub_064:  169 segments (class 0)
# Sub_126:  114 segments (class 0)
# Sub_060:  150 segments (class 0)
# Sub_091:   33 segments (class 1)
# Sub_076:   84 segments (class 1)
# Sub_131:  116 segments (class 0)
# Sub_104:   72 segments (class 0)
# Sub_054:  168 segments (class 0)
# Sub_073:   74 segments (class 1)
# Sub_062:  182 segments (class 0)
# Sub_114:   53 segments (class 0)
# Sub_072:   45 segments (class 1)
# Sub_094:  135 segments (class 1)
# Sub_041:  177 segments (class 0)
# Sub_124:  110 segments (class 0)
# Sub_074:   32 segments (class 1)
# Sub_079:   79 segments (class 1)
# Sub_112:   71 segments (class 0)
# Sub_048:  202 segments (class 0)
# Sub_037:  155 segments (class 0)
# Sub_118:   71 segments (class 0)
# Sub_003:   61 segments (class 1)
# Sub_066:   62 segments (class 1)
# Sub_029:  148 segments (class 1)
# Sub_005:  160 segments (class 1)
# Sub_031:  231 segments (class 1)
# Sub_108:   82 segments (class 0)
# Sub_120:  113 segments (class 0)
# Sub_093:  121 segments (class 1)
# Sub_107:   99 segments (class 0)
# Sub_103:   72 segments (class 0)
# Sub_028:  165 segments (class 1)
# Sub_075:   49 segments (class 1)
# Sub_089:  105 segments (class 1)
# Sub_020:  173 segments (class 1)
# Sub_116:   81 segments (class 0)
# Sub_065:  176 segments (class 0)
# Sub_127:  132 segments (class 0)
#
# Loading Test data:
# ────────────────────────────────────────────────────────────
# Sub_012:  179 segments (class 1)
# Sub_088:   96 segments (class 1)
# Sub_090:   72 segments (class 1)
# Sub_100:   82 segments (class 1)
# Sub_071:   28 segments (class 1)
# Sub_086:   94 segments (class 1)
# Sub_122:  120 segments (class 0)
# Sub_051:  157 segments (class 0)
# Sub_023:  172 segments (class 1)
# Sub_058:  152 segments (class 0)
# Sub_006:  127 segments (class 1)
# Sub_130:  118 segments (class 0)
# Sub_097:  112 segments (class 1)
# Sub_077:   69 segments (class 1)
# Sub_109:   57 segments (class 0)
# Sub_132:  119 segments (class 0)
# Sub_004:  141 segments (class 1)
# Sub_052:  152 segments (class 0)
# Sub_040:  203 segments (class 0)
# Sub_110:  116 segments (class 0)
# Sub_115:   69 segments (class 0)
# Sub_045:  172 segments (class 0)
# Sub_025:  139 segments (class 1)
# Sub_046:  151 segments (class 0)
# Sub_016:  197 segments (class 1)
# Sub_001:  119 segments (class 1)
#
# Applying winsor_zscore normalization (per_channel)...
# Normalization applied successfully
#
# ================================================================================
# Data Preparation Complete for Fold 1
# ================================================================================
#   Train:       (13456, 19, 640)
#   Validation:  None
#   Test:        (3213, 19, 640)
# ================================================================================
#
#
# Dataset split:
#   Train: 13456 samples
#   Val:   None (val_split=0) samples
#   Test:  3213 samples
#
# Model: EEGModel | Device: cuda
# Total parameters: 257,986 | Trainable: 257,986
#
# Training without validation set (using all epochs)...
#
# ================================================================================
# << TRAINING STARTED >>
# ================================================================================
# Device: cuda | Train samples: 13,456
# Batch size: 16 | Effective batch size: 16
# Max epochs: 30 | Early stopping patience: None
# ================================================================================
#
# Epoch [  1/30] | Train Acc:  79.32% | LR: 1.00e-04
# Epoch [  2/30] | Train Acc:  83.18% | LR: 9.97e-05
# Epoch [  3/30] | Train Acc:  84.55% | LR: 9.89e-05
# Epoch [  4/30] | Train Acc:  85.63% | LR: 9.76e-05
# Epoch [  5/30] | Train Acc:  86.36% | LR: 9.57e-05
# Epoch [  6/30] | Train Acc:  86.88% | LR: 9.34e-05
# Epoch [  7/30] | Train Acc:  87.35% | LR: 9.05e-05
# Epoch [  8/30] | Train Acc:  87.51% | LR: 8.73e-05
# Epoch [  9/30] | Train Acc:  87.66% | LR: 8.36e-05
# Epoch [ 10/30] | Train Acc:  88.02% | LR: 7.96e-05
# Epoch [ 11/30] | Train Acc:  88.46% | LR: 7.52e-05
# Epoch [ 12/30] | Train Acc:  88.45% | LR: 7.06e-05
# Epoch [ 13/30] | Train Acc:  88.51% | LR: 6.58e-05
# Epoch [ 14/30] | Train Acc:  88.87% | LR: 6.08e-05
# Epoch [ 15/30] | Train Acc:  88.83% | LR: 5.57e-05
# Epoch [ 16/30] | Train Acc:  88.83% | LR: 5.05e-05
# Epoch [ 17/30] | Train Acc:  88.92% | LR: 4.53e-05
# Epoch [ 18/30] | Train Acc:  88.92% | LR: 4.02e-05
# Epoch [ 19/30] | Train Acc:  89.08% | LR: 3.52e-05
# Epoch [ 20/30] | Train Acc:  89.36% | LR: 3.04e-05
# Epoch [ 21/30] | Train Acc:  88.93% | LR: 2.58e-05
# Epoch [ 22/30] | Train Acc:  89.23% | LR: 2.14e-05
# Epoch [ 23/30] | Train Acc:  89.58% | LR: 1.74e-05
# Epoch [ 24/30] | Train Acc:  89.54% | LR: 1.37e-05
# Epoch [ 25/30] | Train Acc:  89.76% | LR: 1.05e-05
# Epoch [ 26/30] | Train Acc:  89.49% | LR: 7.63e-06
# Epoch [ 27/30] | Train Acc:  89.89% | LR: 5.28e-06
# Epoch [ 28/30] | Train Acc:  89.45% | LR: 3.42e-06
# Epoch [ 29/30] | Train Acc:  89.74% | LR: 2.08e-06
# Epoch [ 30/30] | Train Acc:  89.87% | LR: 1.27e-06
#
# ================================================================================
# TRAINING COMPLETED | Best Val Acc: 0.00%
# ================================================================================
#
#
# === Subject-level Evaluation (26 subjects) ===
# ==================================================
# === Final Subject-Level Metrics ===
# ==================================================
# Evaluated Subjects: 26/26
# Accuracy:             0.8077
# Sensitivity (AD):    0.7857
# Specificity (HC):    0.8333
# Precision (AD):      0.8462
# F1-Score (AD):       0.8148
# ROC-AUC:             0.9048
# ==================================================
#
# ================================================================================
# Fold 1 Test Results
# ================================================================================
#   Accuracy:    0.8077 (80.77%)
#   Sensitivity: 0.7857 (78.57%)
#   Specificity: 0.8333 (83.33%)
#   ROC AUC:     0.9048
#   Precision:   0.8462
#   Recall:      0.7857
#   F1-Score:    0.8148
# ================================================================================
#
#
# ================================================================================
# Segment CSV Files ...
# ================================================================================
#  Fold 1: files saved successfully.
# ================================================================================
#
# Completed 1/5 folds
#
# ================================================================================
# Processing Fold 2
# ================================================================================
#
# ================================================================================
# Preparing Data for Fold 2
# ================================================================================
#   Segments per subject: All
#   Normalization:        winsor_zscore
#   Norm level:           per_channel
#
# Loading Train data:
# ────────────────────────────────────────────────────────────
# Sub_124:  110 segments (class 0)
# Sub_014:  189 segments (class 1)
# Sub_006:  127 segments (class 1)
# Sub_102:   82 segments (class 0)
# Sub_121:  120 segments (class 0)
# Sub_083:  116 segments (class 1)
# Sub_038:  178 segments (class 0)
# Sub_041:  177 segments (class 0)
# Sub_116:   81 segments (class 0)
# Sub_016:  197 segments (class 1)
# Sub_059:  157 segments (class 0)
# Sub_054:  168 segments (class 0)
# Sub_001:  119 segments (class 1)
# Sub_098:   99 segments (class 1)
# Sub_024:  153 segments (class 1)
# Sub_082:   87 segments (class 1)
# Sub_085:  101 segments (class 1)
# Sub_100:   82 segments (class 1)
# Sub_069:   62 segments (class 1)
# Sub_056:  177 segments (class 0)
# Sub_018:  169 segments (class 1)
# Sub_101:   69 segments (class 0)
# Sub_079:   79 segments (class 1)
# Sub_034:  194 segments (class 1)
# Sub_028:  165 segments (class 1)
# Sub_039:  171 segments (class 0)
# Sub_057:  159 segments (class 0)
# Sub_091:   33 segments (class 1)
# Sub_021:  184 segments (class 1)
# Sub_097:  112 segments (class 1)
# Sub_046:  151 segments (class 0)
# Sub_110:  116 segments (class 0)
# Sub_013:  168 segments (class 1)
# Sub_067:   64 segments (class 1)
# Sub_119:   75 segments (class 0)
# Sub_036:  170 segments (class 1)
# Sub_052:  152 segments (class 0)
# Sub_008:  159 segments (class 1)
# Sub_130:  118 segments (class 0)
# Sub_095:  115 segments (class 1)
# Sub_051:  157 segments (class 0)
# Sub_045:  172 segments (class 0)
# Sub_022:  164 segments (class 1)
# Sub_071:   28 segments (class 1)
# Sub_042:  195 segments (class 0)
# Sub_011:  154 segments (class 1)
# Sub_055:  164 segments (class 0)
# Sub_084:  124 segments (class 1)
# Sub_088:   96 segments (class 1)
# Sub_035:  151 segments (class 1)
# Sub_025:  139 segments (class 1)
# Sub_106:   89 segments (class 0)
# Sub_113:   71 segments (class 0)
# Sub_032:  170 segments (class 1)
# Sub_087:  109 segments (class 1)
# Sub_061:  161 segments (class 0)
# Sub_019:  184 segments (class 1)
# Sub_031:  231 segments (class 1)
# Sub_004:  141 segments (class 1)
# Sub_023:  172 segments (class 1)
# Sub_049:  156 segments (class 0)
# Sub_012:  179 segments (class 1)
# Sub_122:  120 segments (class 0)
# Sub_009:  122 segments (class 1)
# Sub_086:   94 segments (class 1)
# Sub_128:  118 segments (class 0)
# Sub_105:   65 segments (class 0)
# Sub_068:   57 segments (class 1)
# Sub_062:  182 segments (class 0)
# Sub_125:  118 segments (class 0)
# Sub_058:  152 segments (class 0)
# Sub_090:   72 segments (class 1)
# Sub_078:   83 segments (class 1)
# Sub_132:  119 segments (class 0)
# Sub_104:   72 segments (class 0)
# Sub_053:  159 segments (class 0)
# Sub_074:   32 segments (class 1)
# Sub_060:  150 segments (class 0)
# Sub_114:   53 segments (class 0)
# Sub_073:   74 segments (class 1)
# Sub_094:  135 segments (class 1)
# Sub_040:  203 segments (class 0)
# Sub_123:  105 segments (class 0)
# Sub_076:   84 segments (class 1)
# Sub_081:   82 segments (class 1)
# Sub_112:   71 segments (class 0)
# Sub_048:  202 segments (class 0)
# Sub_037:  155 segments (class 0)
# Sub_117:   87 segments (class 0)
# Sub_002:  158 segments (class 1)
# Sub_066:   62 segments (class 1)
# Sub_027:  166 segments (class 1)
# Sub_003:   61 segments (class 1)
# Sub_029:  148 segments (class 1)
# Sub_109:   57 segments (class 0)
# Sub_120:  113 segments (class 0)
# Sub_092:  113 segments (class 1)
# Sub_108:   82 segments (class 0)
# Sub_103:   72 segments (class 0)
# Sub_026:  183 segments (class 1)
# Sub_077:   69 segments (class 1)
# Sub_089:  105 segments (class 1)
# Sub_020:  173 segments (class 1)
# Sub_115:   69 segments (class 0)
# Sub_064:  169 segments (class 0)
# Sub_127:  132 segments (class 0)
#
# Loading Test data:
# ────────────────────────────────────────────────────────────
# Sub_015:  182 segments (class 1)
# Sub_080:   90 segments (class 1)
# Sub_093:  121 segments (class 1)
# Sub_099:  116 segments (class 1)
# Sub_070:   80 segments (class 1)
# Sub_075:   49 segments (class 1)
# Sub_126:  114 segments (class 0)
# Sub_050:  165 segments (class 0)
# Sub_030:  111 segments (class 1)
# Sub_065:  176 segments (class 0)
# Sub_010:  258 segments (class 1)
# Sub_129:  108 segments (class 0)
# Sub_096:   99 segments (class 1)
# Sub_072:   45 segments (class 1)
# Sub_107:   99 segments (class 0)
# Sub_131:  116 segments (class 0)
# Sub_007:  153 segments (class 1)
# Sub_063:  161 segments (class 0)
# Sub_043:  165 segments (class 0)
# Sub_111:   73 segments (class 0)
# Sub_118:   71 segments (class 0)
# Sub_044:  176 segments (class 0)
# Sub_033:  141 segments (class 1)
# Sub_047:  161 segments (class 0)
# Sub_017:  169 segments (class 1)
# Sub_005:  160 segments (class 1)
#
# Applying winsor_zscore normalization (per_channel)...
# Normalization applied successfully
#
# ================================================================================
# Data Preparation Complete for Fold 2
# ================================================================================
#   Train:       (13310, 19, 640)
#   Validation:  None
#   Test:        (3359, 19, 640)
# ================================================================================
#
#
# Dataset split:
#   Train: 13310 samples
#   Val:   None (val_split=0) samples
#   Test:  3359 samples
#
# Model: EEGModel | Device: cuda
# Total parameters: 257,986 | Trainable: 257,986
#
# Training without validation set (using all epochs)...
#
# ================================================================================
# << TRAINING STARTED >>
# ================================================================================
# Device: cuda | Train samples: 13,310
# Batch size: 16 | Effective batch size: 16
# Max epochs: 30 | Early stopping patience: None
# ================================================================================
#
# Epoch [  1/30] | Train Acc:  77.56% | LR: 1.00e-04
# Epoch [  2/30] | Train Acc:  80.66% | LR: 9.97e-05
# Epoch [  3/30] | Train Acc:  82.57% | LR: 9.89e-05
# Epoch [  4/30] | Train Acc:  83.45% | LR: 9.76e-05
# Epoch [  5/30] | Train Acc:  84.24% | LR: 9.57e-05
# Epoch [  6/30] | Train Acc:  84.85% | LR: 9.34e-05
# Epoch [  7/30] | Train Acc:  84.63% | LR: 9.05e-05
# Epoch [  8/30] | Train Acc:  85.18% | LR: 8.73e-05
# Epoch [  9/30] | Train Acc:  85.42% | LR: 8.36e-05
# Epoch [ 10/30] | Train Acc:  85.35% | LR: 7.96e-05
# Epoch [ 11/30] | Train Acc:  85.76% | LR: 7.52e-05
# Epoch [ 12/30] | Train Acc:  85.38% | LR: 7.06e-05
# Epoch [ 13/30] | Train Acc:  86.38% | LR: 6.58e-05
# Epoch [ 14/30] | Train Acc:  86.34% | LR: 6.08e-05
# Epoch [ 15/30] | Train Acc:  86.67% | LR: 5.57e-05
# Epoch [ 16/30] | Train Acc:  86.47% | LR: 5.05e-05
# Epoch [ 17/30] | Train Acc:  86.40% | LR: 4.53e-05
# Epoch [ 18/30] | Train Acc:  87.00% | LR: 4.02e-05
# Epoch [ 19/30] | Train Acc:  86.79% | LR: 3.52e-05
# Epoch [ 20/30] | Train Acc:  87.21% | LR: 3.04e-05
# Epoch [ 21/30] | Train Acc:  87.31% | LR: 2.58e-05
# Epoch [ 22/30] | Train Acc:  86.91% | LR: 2.14e-05
# Epoch [ 23/30] | Train Acc:  86.71% | LR: 1.74e-05
# Epoch [ 24/30] | Train Acc:  87.33% | LR: 1.37e-05
# Epoch [ 25/30] | Train Acc:  87.20% | LR: 1.05e-05
# Epoch [ 26/30] | Train Acc:  87.50% | LR: 7.63e-06
# Epoch [ 27/30] | Train Acc:  87.25% | LR: 5.28e-06
# Epoch [ 28/30] | Train Acc:  87.29% | LR: 3.42e-06
# Epoch [ 29/30] | Train Acc:  87.09% | LR: 2.08e-06
# Epoch [ 30/30] | Train Acc:  87.27% | LR: 1.27e-06
#
# ================================================================================
# TRAINING COMPLETED | Best Val Acc: 0.00%
# ================================================================================
#
#
# === Subject-level Evaluation (26 subjects) ===
# ==================================================
# === Final Subject-Level Metrics ===
# ==================================================
# Evaluated Subjects: 26/26
# Accuracy:             0.9231
# Sensitivity (AD):    0.8571
# Specificity (HC):    1.0000
# Precision (AD):      1.0000
# F1-Score (AD):       0.9231
# ROC-AUC:             0.9643
# ==================================================
#
# ================================================================================
# Fold 2 Test Results
# ================================================================================
#   Accuracy:    0.9231 (92.31%)
#   Sensitivity: 0.8571 (85.71%)
#   Specificity: 1.0000 (100.00%)
#   ROC AUC:     0.9643
#   Precision:   1.0000
#   Recall:      0.8571
#   F1-Score:    0.9231
# ================================================================================
#
#
# ================================================================================
# Segment CSV Files ...
# ================================================================================
#  Fold 2: files saved successfully.
# ================================================================================
#
# Completed 2/5 folds
#
# ================================================================================
# Processing Fold 3
# ================================================================================
#
# ================================================================================
# Preparing Data for Fold 3
# ================================================================================
#   Segments per subject: All
#   Normalization:        winsor_zscore
#   Norm level:           per_channel
#
# Loading Train data:
# ────────────────────────────────────────────────────────────
# Sub_040:  203 segments (class 0)
# Sub_081:   82 segments (class 1)
# Sub_080:   90 segments (class 1)
# Sub_067:   64 segments (class 1)
# Sub_057:  159 segments (class 0)
# Sub_119:   75 segments (class 0)
# Sub_132:  119 segments (class 0)
# Sub_061:  161 segments (class 0)
# Sub_011:  154 segments (class 1)
# Sub_001:  119 segments (class 1)
# Sub_025:  139 segments (class 1)
# Sub_041:  177 segments (class 0)
# Sub_112:   71 segments (class 0)
# Sub_122:  120 segments (class 0)
# Sub_098:   99 segments (class 1)
# Sub_005:  160 segments (class 1)
# Sub_101:   69 segments (class 0)
# Sub_043:  165 segments (class 0)
# Sub_015:  182 segments (class 1)
# Sub_035:  151 segments (class 1)
# Sub_127:  132 segments (class 0)
# Sub_069:   62 segments (class 1)
# Sub_029:  148 segments (class 1)
# Sub_097:  112 segments (class 1)
# Sub_056:  177 segments (class 0)
# Sub_092:  113 segments (class 1)
# Sub_019:  184 segments (class 1)
# Sub_054:  168 segments (class 0)
# Sub_051:  157 segments (class 0)
# Sub_010:  258 segments (class 1)
# Sub_108:   82 segments (class 0)
# Sub_012:  179 segments (class 1)
# Sub_131:  116 segments (class 0)
# Sub_099:  116 segments (class 1)
# Sub_037:  155 segments (class 0)
# Sub_100:   82 segments (class 1)
# Sub_006:  127 segments (class 1)
# Sub_076:   84 segments (class 1)
# Sub_070:   80 segments (class 1)
# Sub_050:  165 segments (class 0)
# Sub_045:  172 segments (class 0)
# Sub_021:  184 segments (class 1)
# Sub_083:  116 segments (class 1)
# Sub_044:  176 segments (class 0)
# Sub_008:  159 segments (class 1)
# Sub_055:  164 segments (class 0)
# Sub_088:   96 segments (class 1)
# Sub_089:  105 segments (class 1)
# Sub_036:  170 segments (class 1)
# Sub_026:  183 segments (class 1)
# Sub_107:   99 segments (class 0)
# Sub_033:  141 segments (class 1)
# Sub_093:  121 segments (class 1)
# Sub_063:  161 segments (class 0)
# Sub_016:  197 segments (class 1)
# Sub_031:  231 segments (class 1)
# Sub_004:  141 segments (class 1)
# Sub_023:  172 segments (class 1)
# Sub_048:  202 segments (class 0)
# Sub_009:  122 segments (class 1)
# Sub_102:   82 segments (class 0)
# Sub_007:  153 segments (class 1)
# Sub_086:   94 segments (class 1)
# Sub_046:  151 segments (class 0)
# Sub_115:   69 segments (class 0)
# Sub_106:   89 segments (class 0)
# Sub_068:   57 segments (class 1)
# Sub_064:  169 segments (class 0)
# Sub_090:   72 segments (class 1)
# Sub_058:  152 segments (class 0)
# Sub_128:  118 segments (class 0)
# Sub_075:   49 segments (class 1)
# Sub_129:  108 segments (class 0)
# Sub_125:  118 segments (class 0)
# Sub_052:  152 segments (class 0)
# Sub_072:   45 segments (class 1)
# Sub_062:  182 segments (class 0)
# Sub_114:   53 segments (class 0)
# Sub_071:   28 segments (class 1)
# Sub_096:   99 segments (class 1)
# Sub_042:  195 segments (class 0)
# Sub_126:  114 segments (class 0)
# Sub_073:   74 segments (class 1)
# Sub_077:   69 segments (class 1)
# Sub_111:   73 segments (class 0)
# Sub_047:  161 segments (class 0)
# Sub_038:  178 segments (class 0)
# Sub_118:   71 segments (class 0)
# Sub_002:  158 segments (class 1)
# Sub_066:   62 segments (class 1)
# Sub_028:  165 segments (class 1)
# Sub_003:   61 segments (class 1)
# Sub_030:  111 segments (class 1)
# Sub_110:  116 segments (class 0)
# Sub_120:  113 segments (class 0)
# Sub_094:  135 segments (class 1)
# Sub_109:   57 segments (class 0)
# Sub_104:   72 segments (class 0)
# Sub_027:  166 segments (class 1)
# Sub_074:   32 segments (class 1)
# Sub_091:   33 segments (class 1)
# Sub_017:  169 segments (class 1)
# Sub_116:   81 segments (class 0)
# Sub_065:  176 segments (class 0)
# Sub_130:  118 segments (class 0)
#
# Loading Test data:
# ────────────────────────────────────────────────────────────
# Sub_060:  150 segments (class 0)
# Sub_024:  153 segments (class 1)
# Sub_078:   83 segments (class 1)
# Sub_082:   87 segments (class 1)
# Sub_095:  115 segments (class 1)
# Sub_020:  173 segments (class 1)
# Sub_113:   71 segments (class 0)
# Sub_103:   72 segments (class 0)
# Sub_079:   79 segments (class 1)
# Sub_053:  159 segments (class 0)
# Sub_123:  105 segments (class 0)
# Sub_105:   65 segments (class 0)
# Sub_014:  189 segments (class 1)
# Sub_059:  157 segments (class 0)
# Sub_121:  120 segments (class 0)
# Sub_085:  101 segments (class 1)
# Sub_124:  110 segments (class 0)
# Sub_039:  171 segments (class 0)
# Sub_032:  170 segments (class 1)
# Sub_049:  156 segments (class 0)
# Sub_022:  164 segments (class 1)
# Sub_013:  168 segments (class 1)
# Sub_117:   87 segments (class 0)
# Sub_018:  169 segments (class 1)
# Sub_034:  194 segments (class 1)
# Sub_084:  124 segments (class 1)
# Sub_087:  109 segments (class 1)
#
# Applying winsor_zscore normalization (per_channel)...
# Normalization applied successfully
#
# ================================================================================
# Data Preparation Complete for Fold 3
# ================================================================================
#   Train:       (13168, 19, 640)
#   Validation:  None
#   Test:        (3501, 19, 640)
# ================================================================================
#
#
# Dataset split:
#   Train: 13168 samples
#   Val:   None (val_split=0) samples
#   Test:  3501 samples
#
# Model: EEGModel | Device: cuda
# Total parameters: 257,986 | Trainable: 257,986
#
# Training without validation set (using all epochs)...
#
# ================================================================================
# << TRAINING STARTED >>
# ================================================================================
# Device: cuda | Train samples: 13,168
# Batch size: 16 | Effective batch size: 16
# Max epochs: 30 | Early stopping patience: None
# ================================================================================
#
# Epoch [  1/30] | Train Acc:  74.89% | LR: 1.00e-04
# Epoch [  2/30] | Train Acc:  78.56% | LR: 9.97e-05
# Epoch [  3/30] | Train Acc:  79.55% | LR: 9.89e-05
# Epoch [  4/30] | Train Acc:  80.29% | LR: 9.76e-05
# Epoch [  5/30] | Train Acc:  80.92% | LR: 9.57e-05
# Epoch [  6/30] | Train Acc:  81.12% | LR: 9.34e-05
# Epoch [  7/30] | Train Acc:  81.65% | LR: 9.05e-05
# Epoch [  8/30] | Train Acc:  82.08% | LR: 8.73e-05
# Epoch [  9/30] | Train Acc:  82.77% | LR: 8.36e-05
# Epoch [ 10/30] | Train Acc:  83.07% | LR: 7.96e-05
# Epoch [ 11/30] | Train Acc:  82.93% | LR: 7.52e-05
# Epoch [ 12/30] | Train Acc:  82.64% | LR: 7.06e-05
# Epoch [ 13/30] | Train Acc:  83.35% | LR: 6.58e-05
# Epoch [ 14/30] | Train Acc:  83.34% | LR: 6.08e-05
# Epoch [ 15/30] | Train Acc:  83.70% | LR: 5.57e-05
# Epoch [ 16/30] | Train Acc:  83.35% | LR: 5.05e-05
# Epoch [ 17/30] | Train Acc:  83.63% | LR: 4.53e-05
# Epoch [ 18/30] | Train Acc:  84.04% | LR: 4.02e-05
# Epoch [ 19/30] | Train Acc:  84.12% | LR: 3.52e-05
# Epoch [ 20/30] | Train Acc:  84.33% | LR: 3.04e-05
# Epoch [ 21/30] | Train Acc:  83.98% | LR: 2.58e-05
# Epoch [ 22/30] | Train Acc:  83.98% | LR: 2.14e-05
# Epoch [ 23/30] | Train Acc:  84.55% | LR: 1.74e-05
# Epoch [ 24/30] | Train Acc:  84.37% | LR: 1.37e-05
# Epoch [ 25/30] | Train Acc:  84.90% | LR: 1.05e-05
# Epoch [ 26/30] | Train Acc:  84.56% | LR: 7.63e-06
# Epoch [ 27/30] | Train Acc:  84.36% | LR: 5.28e-06
# Epoch [ 28/30] | Train Acc:  84.39% | LR: 3.42e-06
# Epoch [ 29/30] | Train Acc:  84.21% | LR: 2.08e-06
# Epoch [ 30/30] | Train Acc:  84.57% | LR: 1.27e-06
#
# ================================================================================
# TRAINING COMPLETED | Best Val Acc: 0.00%
# ================================================================================
#
#
# === Subject-level Evaluation (27 subjects) ===
# ==================================================
# === Final Subject-Level Metrics ===
# ==================================================
# Evaluated Subjects: 27/27
# Accuracy:             0.9630
# Sensitivity (AD):    0.9333
# Specificity (HC):    1.0000
# Precision (AD):      1.0000
# F1-Score (AD):       0.9655
# ROC-AUC:             0.9722
# ==================================================
#
# ================================================================================
# Fold 3 Test Results
# ================================================================================
#   Accuracy:    0.9630 (96.30%)
#   Sensitivity: 0.9333 (93.33%)
#   Specificity: 1.0000 (100.00%)
#   ROC AUC:     0.9722
#   Precision:   1.0000
#   Recall:      0.9333
#   F1-Score:    0.9655
# ================================================================================
#
#
# ================================================================================
# Segment CSV Files ...
# ================================================================================
#  Fold 3: files saved successfully.
# ================================================================================
#
# Completed 3/5 folds
#
# ================================================================================
# Processing Fold 4
# ================================================================================
#
# ================================================================================
# Preparing Data for Fold 4
# ================================================================================
#   Segments per subject: All
#   Normalization:        winsor_zscore
#   Norm level:           per_channel
#
# Loading Train data:
# ────────────────────────────────────────────────────────────
# Sub_126:  114 segments (class 0)
# Sub_012:  179 segments (class 1)
# Sub_006:  127 segments (class 1)
# Sub_102:   82 segments (class 0)
# Sub_122:  120 segments (class 0)
# Sub_083:  116 segments (class 1)
# Sub_038:  178 segments (class 0)
# Sub_041:  177 segments (class 0)
# Sub_117:   87 segments (class 0)
# Sub_013:  168 segments (class 1)
# Sub_058:  152 segments (class 0)
# Sub_051:  157 segments (class 0)
# Sub_001:  119 segments (class 1)
# Sub_099:  116 segments (class 1)
# Sub_020:  173 segments (class 1)
# Sub_082:   87 segments (class 1)
# Sub_085:  101 segments (class 1)
# Sub_100:   82 segments (class 1)
# Sub_072:   45 segments (class 1)
# Sub_053:  159 segments (class 0)
# Sub_014:  189 segments (class 1)
# Sub_101:   69 segments (class 0)
# Sub_079:   79 segments (class 1)
# Sub_033:  141 segments (class 1)
# Sub_025:  139 segments (class 1)
# Sub_039:  171 segments (class 0)
# Sub_056:  177 segments (class 0)
# Sub_093:  121 segments (class 1)
# Sub_017:  169 segments (class 1)
# Sub_098:   99 segments (class 1)
# Sub_045:  172 segments (class 0)
# Sub_111:   73 segments (class 0)
# Sub_011:  154 segments (class 1)
# Sub_070:   80 segments (class 1)
# Sub_120:  113 segments (class 0)
# Sub_035:  151 segments (class 1)
# Sub_049:  156 segments (class 0)
# Sub_007:  153 segments (class 1)
# Sub_131:  116 segments (class 0)
# Sub_097:  112 segments (class 1)
# Sub_048:  202 segments (class 0)
# Sub_044:  176 segments (class 0)
# Sub_018:  169 segments (class 1)
# Sub_073:   74 segments (class 1)
# Sub_043:  165 segments (class 0)
# Sub_009:  122 segments (class 1)
# Sub_052:  152 segments (class 0)
# Sub_084:  124 segments (class 1)
# Sub_088:   96 segments (class 1)
# Sub_034:  194 segments (class 1)
# Sub_022:  164 segments (class 1)
# Sub_108:   82 segments (class 0)
# Sub_113:   71 segments (class 0)
# Sub_032:  170 segments (class 1)
# Sub_087:  109 segments (class 1)
# Sub_060:  150 segments (class 0)
# Sub_015:  182 segments (class 1)
# Sub_030:  111 segments (class 1)
# Sub_005:  160 segments (class 1)
# Sub_019:  184 segments (class 1)
# Sub_047:  161 segments (class 0)
# Sub_010:  258 segments (class 1)
# Sub_123:  105 segments (class 0)
# Sub_008:  159 segments (class 1)
# Sub_086:   94 segments (class 1)
# Sub_130:  118 segments (class 0)
# Sub_107:   99 segments (class 0)
# Sub_071:   28 segments (class 1)
# Sub_063:  161 segments (class 0)
# Sub_128:  118 segments (class 0)
# Sub_057:  159 segments (class 0)
# Sub_091:   33 segments (class 1)
# Sub_078:   83 segments (class 1)
# Sub_132:  119 segments (class 0)
# Sub_105:   65 segments (class 0)
# Sub_050:  165 segments (class 0)
# Sub_075:   49 segments (class 1)
# Sub_059:  157 segments (class 0)
# Sub_114:   53 segments (class 0)
# Sub_074:   32 segments (class 1)
# Sub_096:   99 segments (class 1)
# Sub_040:  203 segments (class 0)
# Sub_124:  110 segments (class 0)
# Sub_076:   84 segments (class 1)
# Sub_080:   90 segments (class 1)
# Sub_112:   71 segments (class 0)
# Sub_046:  151 segments (class 0)
# Sub_037:  155 segments (class 0)
# Sub_118:   71 segments (class 0)
# Sub_002:  158 segments (class 1)
# Sub_067:   64 segments (class 1)
# Sub_024:  153 segments (class 1)
# Sub_004:  141 segments (class 1)
# Sub_028:  165 segments (class 1)
# Sub_110:  116 segments (class 0)
# Sub_121:  120 segments (class 0)
# Sub_095:  115 segments (class 1)
# Sub_109:   57 segments (class 0)
# Sub_103:   72 segments (class 0)
# Sub_023:  172 segments (class 1)
# Sub_077:   69 segments (class 1)
# Sub_090:   72 segments (class 1)
# Sub_016:  197 segments (class 1)
# Sub_115:   69 segments (class 0)
# Sub_065:  176 segments (class 0)
# Sub_129:  108 segments (class 0)
#
# Loading Test data:
# ────────────────────────────────────────────────────────────
# Sub_027:  166 segments (class 1)
# Sub_081:   82 segments (class 1)
# Sub_089:  105 segments (class 1)
# Sub_094:  135 segments (class 1)
# Sub_066:   62 segments (class 1)
# Sub_069:   62 segments (class 1)
# Sub_119:   75 segments (class 0)
# Sub_061:  161 segments (class 0)
# Sub_031:  231 segments (class 1)
# Sub_064:  169 segments (class 0)
# Sub_026:  183 segments (class 1)
# Sub_125:  118 segments (class 0)
# Sub_092:  113 segments (class 1)
# Sub_068:   57 segments (class 1)
# Sub_104:   72 segments (class 0)
# Sub_127:  132 segments (class 0)
# Sub_021:  184 segments (class 1)
# Sub_062:  182 segments (class 0)
# Sub_042:  195 segments (class 0)
# Sub_106:   89 segments (class 0)
# Sub_116:   81 segments (class 0)
# Sub_054:  168 segments (class 0)
# Sub_036:  170 segments (class 1)
# Sub_055:  164 segments (class 0)
# Sub_029:  148 segments (class 1)
# Sub_003:   61 segments (class 1)
#
# Applying winsor_zscore normalization (per_channel)...
# Normalization applied successfully
#
# ================================================================================
# Data Preparation Complete for Fold 4
# ================================================================================
#   Train:       (13304, 19, 640)
#   Validation:  None
#   Test:        (3365, 19, 640)
# ================================================================================
#
#
# Dataset split:
#   Train: 13304 samples
#   Val:   None (val_split=0) samples
#   Test:  3365 samples
#
# Model: EEGModel | Device: cuda
# Total parameters: 257,986 | Trainable: 257,986
#
# Training without validation set (using all epochs)...
#
# ================================================================================
# << TRAINING STARTED >>
# ================================================================================
# Device: cuda | Train samples: 13,304
# Batch size: 16 | Effective batch size: 16
# Max epochs: 30 | Early stopping patience: None
# ================================================================================
#
# Epoch [  1/30] | Train Acc:  75.54% | LR: 1.00e-04
# Epoch [  2/30] | Train Acc:  79.37% | LR: 9.97e-05
# Epoch [  3/30] | Train Acc:  80.42% | LR: 9.89e-05
# Epoch [  4/30] | Train Acc:  80.99% | LR: 9.76e-05
# Epoch [  5/30] | Train Acc:  81.44% | LR: 9.57e-05
# Epoch [  6/30] | Train Acc:  82.38% | LR: 9.34e-05
# Epoch [  7/30] | Train Acc:  82.30% | LR: 9.05e-05
# Epoch [  8/30] | Train Acc:  82.99% | LR: 8.73e-05
# Epoch [  9/30] | Train Acc:  83.12% | LR: 8.36e-05
# Epoch [ 10/30] | Train Acc:  83.32% | LR: 7.96e-05
# Epoch [ 11/30] | Train Acc:  83.54% | LR: 7.52e-05
# Epoch [ 12/30] | Train Acc:  83.71% | LR: 7.06e-05
# Epoch [ 13/30] | Train Acc:  84.03% | LR: 6.58e-05
# Epoch [ 14/30] | Train Acc:  84.53% | LR: 6.08e-05
# Epoch [ 15/30] | Train Acc:  84.03% | LR: 5.57e-05
# Epoch [ 16/30] | Train Acc:  84.60% | LR: 5.05e-05
# Epoch [ 17/30] | Train Acc:  84.97% | LR: 4.53e-05
# Epoch [ 18/30] | Train Acc:  84.86% | LR: 4.02e-05
# Epoch [ 19/30] | Train Acc:  84.95% | LR: 3.52e-05
# Epoch [ 20/30] | Train Acc:  84.95% | LR: 3.04e-05
# Epoch [ 21/30] | Train Acc:  85.28% | LR: 2.58e-05
# Epoch [ 22/30] | Train Acc:  84.88% | LR: 2.14e-05
# Epoch [ 23/30] | Train Acc:  85.51% | LR: 1.74e-05
# Epoch [ 24/30] | Train Acc:  85.00% | LR: 1.37e-05
# Epoch [ 25/30] | Train Acc:  84.96% | LR: 1.05e-05
# Epoch [ 26/30] | Train Acc:  85.03% | LR: 7.63e-06
# Epoch [ 27/30] | Train Acc:  85.17% | LR: 5.28e-06
# Epoch [ 28/30] | Train Acc:  85.66% | LR: 3.42e-06
# Epoch [ 29/30] | Train Acc:  86.00% | LR: 2.08e-06
# Epoch [ 30/30] | Train Acc:  85.60% | LR: 1.27e-06
#
# ================================================================================
# TRAINING COMPLETED | Best Val Acc: 0.00%
# ================================================================================
#
#
# === Subject-level Evaluation (26 subjects) ===
# ==================================================
# === Final Subject-Level Metrics ===
# ==================================================
# Evaluated Subjects: 26/26
# Accuracy:             0.9615
# Sensitivity (AD):    0.9286
# Specificity (HC):    1.0000
# Precision (AD):      1.0000
# F1-Score (AD):       0.9630
# ROC-AUC:             0.9940
# ==================================================
#
# ================================================================================
# Fold 4 Test Results
# ================================================================================
#   Accuracy:    0.9615 (96.15%)
#   Sensitivity: 0.9286 (92.86%)
#   Specificity: 1.0000 (100.00%)
#   ROC AUC:     0.9940
#   Precision:   1.0000
#   Recall:      0.9286
#   F1-Score:    0.9630
# ================================================================================
#
#
# ================================================================================
# Segment CSV Files ...
# ================================================================================
#  Fold 4: files saved successfully.
# ================================================================================
#
# Completed 4/5 folds
#
# ================================================================================
# Processing Fold 5
# ================================================================================
#
# ================================================================================
# Preparing Data for Fold 5
# ================================================================================
#   Segments per subject: All
#   Normalization:        winsor_zscore
#   Norm level:           per_channel
#
# Loading Train data:
# ────────────────────────────────────────────────────────────
# Sub_040:  203 segments (class 0)
# Sub_084:  124 segments (class 1)
# Sub_082:   87 segments (class 1)
# Sub_068:   57 segments (class 1)
# Sub_059:  157 segments (class 0)
# Sub_121:  120 segments (class 0)
# Sub_132:  119 segments (class 0)
# Sub_061:  161 segments (class 0)
# Sub_015:  182 segments (class 1)
# Sub_001:  119 segments (class 1)
# Sub_024:  153 segments (class 1)
# Sub_042:  195 segments (class 0)
# Sub_115:   69 segments (class 0)
# Sub_123:  105 segments (class 0)
# Sub_097:  112 segments (class 1)
# Sub_006:  127 segments (class 1)
# Sub_103:   72 segments (class 0)
# Sub_044:  176 segments (class 0)
# Sub_017:  169 segments (class 1)
# Sub_033:  141 segments (class 1)
# Sub_126:  114 segments (class 0)
# Sub_070:   80 segments (class 1)
# Sub_029:  148 segments (class 1)
# Sub_096:   99 segments (class 1)
# Sub_058:  152 segments (class 0)
# Sub_092:  113 segments (class 1)
# Sub_021:  184 segments (class 1)
# Sub_054:  168 segments (class 0)
# Sub_052:  152 segments (class 0)
# Sub_014:  189 segments (class 1)
# Sub_109:   57 segments (class 0)
# Sub_016:  197 segments (class 1)
# Sub_131:  116 segments (class 0)
# Sub_099:  116 segments (class 1)
# Sub_036:  170 segments (class 1)
# Sub_100:   82 segments (class 1)
# Sub_007:  153 segments (class 1)
# Sub_080:   90 segments (class 1)
# Sub_071:   28 segments (class 1)
# Sub_051:  157 segments (class 0)
# Sub_046:  151 segments (class 0)
# Sub_022:  164 segments (class 1)
# Sub_085:  101 segments (class 1)
# Sub_045:  172 segments (class 0)
# Sub_012:  179 segments (class 1)
# Sub_055:  164 segments (class 0)
# Sub_087:  109 segments (class 1)
# Sub_088:   96 segments (class 1)
# Sub_034:  194 segments (class 1)
# Sub_025:  139 segments (class 1)
# Sub_107:   99 segments (class 0)
# Sub_032:  170 segments (class 1)
# Sub_093:  121 segments (class 1)
# Sub_063:  161 segments (class 0)
# Sub_018:  169 segments (class 1)
# Sub_031:  231 segments (class 1)
# Sub_005:  160 segments (class 1)
# Sub_023:  172 segments (class 1)
# Sub_050:  165 segments (class 0)
# Sub_013:  168 segments (class 1)
# Sub_104:   72 segments (class 0)
# Sub_010:  258 segments (class 1)
# Sub_086:   94 segments (class 1)
# Sub_047:  161 segments (class 0)
# Sub_117:   87 segments (class 0)
# Sub_106:   89 segments (class 0)
# Sub_069:   62 segments (class 1)
# Sub_064:  169 segments (class 0)
# Sub_089:  105 segments (class 1)
# Sub_060:  150 segments (class 0)
# Sub_127:  132 segments (class 0)
# Sub_079:   79 segments (class 1)
# Sub_129:  108 segments (class 0)
# Sub_124:  110 segments (class 0)
# Sub_053:  159 segments (class 0)
# Sub_075:   49 segments (class 1)
# Sub_062:  182 segments (class 0)
# Sub_116:   81 segments (class 0)
# Sub_072:   45 segments (class 1)
# Sub_095:  115 segments (class 1)
# Sub_043:  165 segments (class 0)
# Sub_125:  118 segments (class 0)
# Sub_077:   69 segments (class 1)
# Sub_081:   82 segments (class 1)
# Sub_113:   71 segments (class 0)
# Sub_049:  156 segments (class 0)
# Sub_039:  171 segments (class 0)
# Sub_119:   75 segments (class 0)
# Sub_003:   61 segments (class 1)
# Sub_066:   62 segments (class 1)
# Sub_027:  166 segments (class 1)
# Sub_004:  141 segments (class 1)
# Sub_030:  111 segments (class 1)
# Sub_111:   73 segments (class 0)
# Sub_122:  120 segments (class 0)
# Sub_094:  135 segments (class 1)
# Sub_110:  116 segments (class 0)
# Sub_105:   65 segments (class 0)
# Sub_026:  183 segments (class 1)
# Sub_078:   83 segments (class 1)
# Sub_090:   72 segments (class 1)
# Sub_020:  173 segments (class 1)
# Sub_118:   71 segments (class 0)
# Sub_065:  176 segments (class 0)
# Sub_130:  118 segments (class 0)
#
# Loading Test data:
# ────────────────────────────────────────────────────────────
# Sub_057:  159 segments (class 0)
# Sub_028:  165 segments (class 1)
# Sub_067:   64 segments (class 1)
# Sub_074:   32 segments (class 1)
# Sub_098:   99 segments (class 1)
# Sub_011:  154 segments (class 1)
# Sub_108:   82 segments (class 0)
# Sub_101:   69 segments (class 0)
# Sub_073:   74 segments (class 1)
# Sub_048:  202 segments (class 0)
# Sub_120:  113 segments (class 0)
# Sub_102:   82 segments (class 0)
# Sub_008:  159 segments (class 1)
# Sub_056:  177 segments (class 0)
# Sub_114:   53 segments (class 0)
# Sub_083:  116 segments (class 1)
# Sub_128:  118 segments (class 0)
# Sub_038:  178 segments (class 0)
# Sub_035:  151 segments (class 1)
# Sub_041:  177 segments (class 0)
# Sub_019:  184 segments (class 1)
# Sub_002:  158 segments (class 1)
# Sub_112:   71 segments (class 0)
# Sub_009:  122 segments (class 1)
# Sub_037:  155 segments (class 0)
# Sub_076:   84 segments (class 1)
# Sub_091:   33 segments (class 1)
#
# Applying winsor_zscore normalization (per_channel)...
# Normalization applied successfully
#
# ================================================================================
# Data Preparation Complete for Fold 5
# ================================================================================
#   Train:       (13438, 19, 640)
#   Validation:  None
#   Test:        (3231, 19, 640)
# ================================================================================
#
#
# Dataset split:
#   Train: 13438 samples
#   Val:   None (val_split=0) samples
#   Test:  3231 samples
#
# Model: EEGModel | Device: cuda
# Total parameters: 257,986 | Trainable: 257,986
#
# Training without validation set (using all epochs)...
#
# ================================================================================
# << TRAINING STARTED >>
# ================================================================================
# Device: cuda | Train samples: 13,438
# Batch size: 16 | Effective batch size: 16
# Max epochs: 30 | Early stopping patience: None
# ================================================================================
#
# Epoch [  1/30] | Train Acc:  76.21% | LR: 1.00e-04
# Epoch [  2/30] | Train Acc:  80.19% | LR: 9.97e-05
# Epoch [  3/30] | Train Acc:  81.48% | LR: 9.89e-05
# Epoch [  4/30] | Train Acc:  82.70% | LR: 9.76e-05
# Epoch [  5/30] | Train Acc:  83.32% | LR: 9.57e-05
# Epoch [  6/30] | Train Acc:  83.84% | LR: 9.34e-05
# Epoch [  7/30] | Train Acc:  84.36% | LR: 9.05e-05
# Epoch [  8/30] | Train Acc:  84.64% | LR: 8.73e-05
# Epoch [  9/30] | Train Acc:  85.21% | LR: 8.36e-05
# Epoch [ 10/30] | Train Acc:  85.19% | LR: 7.96e-05
# Epoch [ 11/30] | Train Acc:  85.29% | LR: 7.52e-05
# Epoch [ 12/30] | Train Acc:  85.97% | LR: 7.06e-05
# Epoch [ 13/30] | Train Acc:  85.43% | LR: 6.58e-05
# Epoch [ 14/30] | Train Acc:  86.10% | LR: 6.08e-05
# Epoch [ 15/30] | Train Acc:  86.04% | LR: 5.57e-05
# Epoch [ 16/30] | Train Acc:  86.15% | LR: 5.05e-05
# Epoch [ 17/30] | Train Acc:  86.27% | LR: 4.53e-05
# Epoch [ 18/30] | Train Acc:  86.12% | LR: 4.02e-05
# Epoch [ 19/30] | Train Acc:  86.78% | LR: 3.52e-05
# Epoch [ 20/30] | Train Acc:  86.79% | LR: 3.04e-05
# Epoch [ 21/30] | Train Acc:  86.80% | LR: 2.58e-05
# Epoch [ 22/30] | Train Acc:  86.67% | LR: 2.14e-05
# Epoch [ 23/30] | Train Acc:  86.74% | LR: 1.74e-05
# Epoch [ 24/30] | Train Acc:  86.76% | LR: 1.37e-05
# Epoch [ 25/30] | Train Acc:  87.39% | LR: 1.05e-05
# Epoch [ 26/30] | Train Acc:  87.17% | LR: 7.63e-06
# Epoch [ 27/30] | Train Acc:  87.37% | LR: 5.28e-06
# Epoch [ 28/30] | Train Acc:  86.96% | LR: 3.42e-06
# Epoch [ 29/30] | Train Acc:  87.32% | LR: 2.08e-06
# Epoch [ 30/30] | Train Acc:  86.94% | LR: 1.27e-06
#
# ================================================================================
# TRAINING COMPLETED | Best Val Acc: 0.00%
# ================================================================================
#
#
# === Subject-level Evaluation (27 subjects) ===
# ==================================================
# === Final Subject-Level Metrics ===
# ==================================================
# Evaluated Subjects: 27/27
# Accuracy:             0.9259
# Sensitivity (AD):    0.8571
# Specificity (HC):    1.0000
# Precision (AD):      1.0000
# F1-Score (AD):       0.9231
# ROC-AUC:             0.9780
# ==================================================
#
# ================================================================================
# Fold 5 Test Results
# ================================================================================
#   Accuracy:    0.9259 (92.59%)
#   Sensitivity: 0.8571 (85.71%)
#   Specificity: 1.0000 (100.00%)
#   ROC AUC:     0.9780
#   Precision:   1.0000
#   Recall:      0.8571
#   F1-Score:    0.9231
# ================================================================================
#
#
# ================================================================================
# Segment CSV Files ...
# ================================================================================
#  Fold 5: files saved successfully.
# ================================================================================
#
# Completed 5/5 folds
#
# Complete raw results object saved to: /teamspace/studios/this_studio/Phd/experiment/Combined/results/ApplaitionM3/tables/raw_all_fold_results.pkl
#
# ================================================================================
# FINAL CROSS-VALIDATION RESULTS
# ================================================================================
#
# Performance Summary (Mean ± Std):
# --------------------------------------------------------------------------------
#   Accuracy       : 0.9162 ± 0.0636 [0.8077, 0.9630]
#   Roc Auc        : 0.9627 ± 0.0342 [0.9048, 0.9940]
#   Sensitivity    : 0.8724 ± 0.0609 [0.7857, 0.9333]
#   Specificity    : 0.9667 ± 0.0745 [0.8333, 1.0000]
#   Precision      : 0.9692 ± 0.0688 [0.8462, 1.0000]
#   Recall         : 0.8724 ± 0.0609 [0.7857, 0.9333]
#   F1 Score       : 0.9179 ± 0.0612 [0.8148, 0.9655]
#
# ================================================================================
# Individual Fold Results
# ================================================================================
#   Fold | Accuracy |       F1 |      AUC |     Sens |     Spec
# --------------------------------------------------------------------------------
#      1 |   0.8077 |   0.8148 |   0.9048 |   0.7857 |   0.8333
#      2 |   0.9231 |   0.9231 |   0.9643 |   0.8571 |   1.0000
#      3 |   0.9630 |   0.9655 |   0.9722 |   0.9333 |   1.0000
#      4 |   0.9615 |   0.9630 |   0.9940 |   0.9286 |   1.0000
#      5 |   0.9259 |   0.9231 |   0.9780 |   0.8571 |   1.0000
# ================================================================================
#
# Results saved to: /teamspace/studios/this_studio/Phd/experiment/Combined/results/ApplaitionM3/tables/cv_results_manual132_5folds.csv
#
# 95% Confidence Intervals:
# --------------------------------------------------------------------------------
#   Accuracy       : 0.9162 [0.8605, 0.9719]
#   Roc Auc        : 0.9627 [0.9327, 0.9926]
#   Sensitivity    : 0.8724 [0.8190, 0.9258]
#   Specificity    : 0.9667 [0.9013, 1.0000]
#   Precision      : 0.9692 [0.9089, 1.0000]
#   Recall         : 0.8724 [0.8190, 0.9258]
#   F1 Score       : 0.9179 [0.8643, 0.9715]
# ================================================================================
# Confidence intervals saved to: /teamspace/studios/this_studio/Phd/experiment/Combined/results/ApplaitionM3/tables/confidence_intervals.csv
#
# Full model config, parameters & best fold metrics successfully saved to: /teamspace/studios/this_studio/Phd/experiment/Combined/results/ApplaitionM3/model_info.json
#
#  Subject-level voting proportions successfully saved to: /teamspace/studios/this_studio/Phd/experiment/Combined/results/ApplaitionM3/tables/subject_level_voting_proportions.csv
#
# ================================================================================
# PIPELINE COMPLETED SUCCESSFULLY!
# ================================================================================
# Successful folds: 5/5
#
# ================================================================================
# Generating Plots From Saved Results: /teamspace/studios/this_studio/Phd/experiment/Combined/results/ApplaitionM3/tables/raw_all_fold_results.pkl
# ================================================================================
# Training curves saved: /teamspace/studios/this_studio/Phd/experiment/Combined/results/ApplaitionM3/plots/fold_1_training_curves.png
# Confusion matrix saved: /teamspace/studios/this_studio/Phd/experiment/Combined/results/ApplaitionM3/plots/fold_1_confusion_matrix.png
# Training curves saved: /teamspace/studios/this_studio/Phd/experiment/Combined/results/ApplaitionM3/plots/fold_2_training_curves.png
# Confusion matrix saved: /teamspace/studios/this_studio/Phd/experiment/Combined/results/ApplaitionM3/plots/fold_2_confusion_matrix.png
# Training curves saved: /teamspace/studios/this_studio/Phd/experiment/Combined/results/ApplaitionM3/plots/fold_3_training_curves.png
# Confusion matrix saved: /teamspace/studios/this_studio/Phd/experiment/Combined/results/ApplaitionM3/plots/fold_3_confusion_matrix.png
# Training curves saved: /teamspace/studios/this_studio/Phd/experiment/Combined/results/ApplaitionM3/plots/fold_4_training_curves.png
# Confusion matrix saved: /teamspace/studios/this_studio/Phd/experiment/Combined/results/ApplaitionM3/plots/fold_4_confusion_matrix.png
# Training curves saved: /teamspace/studios/this_studio/Phd/experiment/Combined/results/ApplaitionM3/plots/fold_5_training_curves.png
# Confusion matrix saved: /teamspace/studios/this_studio/Phd/experiment/Combined/results/ApplaitionM3/plots/fold_5_confusion_matrix.png
#
# ================================================================================
# Cross-Validation Summary
# ================================================================================
#   Accuracy:     0.9162 ± 0.0568
#   AUC:          0.9627 ± 0.0306
#   Sensitivity:  0.8724 ± 0.0545
#   Specificity:  0.9667 ± 0.0667
#   F1-Score:     0.9179 ± 0.0547
# ================================================================================
#
# Mean confusion matrix saved: /teamspace/studios/this_studio/Phd/experiment/Combined/results/ApplaitionM3/plots/mean_confusion_matrix.png
# ROC curve saved: /teamspace/studios/this_studio/Phd/experiment/Combined/results/ApplaitionM3/plots/roc_publication.png
