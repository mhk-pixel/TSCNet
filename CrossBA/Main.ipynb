# %%
# ============================================================================
# EEG Classification Pipeline 
# ============================================================================
import sys
sys.path.append("/teamspace/studios/this_studio/Phd")
from src.tools import tools
from config import config
# ============================================================================
# MAIN EXECUTION
# ============================================================================
def main():
    modules = tools()
    modules.set_seed(seed=modules.config['random_state'])
    modules.print_config()
    modules.setup_output_directory()
    
    try:
        print("\nGet dataset...")  
        folds = modules.dataset.prepare_CrossDataset()
        
        print(f"\nCreated {len(folds)} folds")
        print(f"\n{'='*80}\nStarting {modules.config['k_folds']}-fold cross-validation\n{'='*80}")
        
        all_fold_results = []
        successful_folds = 0
        
        for fold_config in folds:
            modules.set_seed(seed=modules.config['random_state'])
            result = modules.run_single_fold(fold_config)
            if result is not None:
                modules.save_segment_details(result)
                all_fold_results.append(result)
                successful_folds += 1
                print(f"\nCompleted {successful_folds}/{len(folds)} folds")
                
        modules.save_all_fold_details(all_fold_results)
        #=======================================================================
        if all_fold_results:
            modules.print_final_results(all_fold_results)
            modules.save_subject_voting_proportions(all_fold_results)
            print(f"\n{'='*80}\nPIPELINE COMPLETED SUCCESSFULLY!\n{'='*80}")
            print(f"Successful folds: {successful_folds}/{len(folds)}")
            
            #=========================================
            modules.generate_plots_from_saved_results()
            modules.save_segment_csvs_from_results()
            t = modules.save_subject_voting_proportions(all_fold_results)
            modules.report_performance_separately(t)
            
        else:
            print(f"\n{'!'*80}\nPIPELINE FAILED - No folds completed successfully\n{'!'*80}")

    except Exception as e:
        print(f"\n{'!'*80}\nPIPELINE FAILED: {e}\n{'!'*80}")
        traceback.print_exc()
    
    finally:
        modules.clear_memory()
        print("\nMemory cleanup completed")   


if __name__ == "__main__":
    main()
# Out:
# Loading information from: /teamspace/studios/this_studio/phdResearch/data2/Labels/labels.csv
# Contains 67 Subjects
# Loading information from: /teamspace/studios/this_studio/phdResearch/data1/Labels/labels.csv
# Contains 65 Subjects
#
# ================================================================================
# EEG CLASSIFICATION PIPELINE
# Mode: Train-Test Split (No Validation)
# ================================================================================
# Configuration:
# --------------------------------------------------------------------------------
#   Dataset path:
#   Device:            cuda
#   Model choice:      0
#   Fold strategy:
#   Number of folds:   1
#   Validation split:  None
#   Early stopping:    Disabled
#
# Stratification: on (['Group'])
#
# Data Settings:
#   Class names:       ['HC', 'AD']
#   Normalization:     minmax
#   Norm level:        per_sample
#
# Training Settings:
#   Batch size:        16
#   Learning rate:     0.001
#   Max epochs:        6
#
# Evaluation Settings:
#   Aggregation mode:  majority
#   Confidence filter: 0.7
#   Save models:       True
# ================================================================================
# Existing experiment directory deleted: /teamspace/studios/this_studio/Phd/experiment/CrossBA/results/CrossBAGitHub
#
# Output directory setup complete: /teamspace/studios/this_studio/Phd/experiment/CrossBA/results/CrossBAGitHub
#
# Get dataset...
#
# Fold 1:
#   Train: 67 subjects
#   Val:   None
#   Test:  65 subjects
#
# Created 1 folds
#
# ================================================================================
# Starting 1-fold cross-validation
# ================================================================================
#
# ================================================================================
# Processing Fold 1
# ================================================================================
#
# ================================================================================
# Preparing Data for Fold 1
# ================================================================================
#   Segments per subject: All
#   Normalization:        minmax
#   Norm level:           per_sample
#
# Loading Train data:
# ────────────────────────────────────────────────────────────
# Sub_037:   82 segments (class 0)
# Sub_017:   87 segments (class 1)
# Sub_005:   80 segments (class 1)
# Sub_010:   49 segments (class 1)
# Sub_046:   73 segments (class 0)
# Sub_041:   89 segments (class 0)
# Sub_062:  132 segments (class 0)
# Sub_006:   28 segments (class 1)
# Sub_065:  118 segments (class 0)
# Sub_013:   83 segments (class 1)
# Sub_026:   33 segments (class 1)
# Sub_060:  118 segments (class 0)
# Sub_029:  135 segments (class 1)
# Sub_001:   62 segments (class 1)
# Sub_063:  118 segments (class 0)
# Sub_035:   82 segments (class 1)
# Sub_049:   53 segments (class 0)
# Sub_008:   74 segments (class 1)
# Sub_042:   99 segments (class 0)
# Sub_031:   99 segments (class 1)
# Sub_055:  113 segments (class 0)
# Sub_020:  101 segments (class 1)
# Sub_045:  116 segments (class 0)
# Sub_043:   82 segments (class 0)
# Sub_032:  112 segments (class 1)
# Sub_047:   71 segments (class 0)
# Sub_014:   79 segments (class 1)
# Sub_054:   75 segments (class 0)
# Sub_004:   62 segments (class 1)
# Sub_018:  116 segments (class 1)
# Sub_034:  116 segments (class 1)
# Sub_009:   32 segments (class 1)
# Sub_048:   71 segments (class 0)
# Sub_007:   45 segments (class 1)
# Sub_067:  119 segments (class 0)
# Sub_066:  116 segments (class 0)
# Sub_016:   82 segments (class 1)
# Sub_028:  121 segments (class 1)
# Sub_027:  113 segments (class 1)
# Sub_025:   72 segments (class 1)
# Sub_051:   81 segments (class 0)
# Sub_012:   69 segments (class 1)
# Sub_033:   99 segments (class 1)
# Sub_064:  108 segments (class 0)
# Sub_050:   69 segments (class 0)
# Sub_038:   72 segments (class 0)
# Sub_030:  115 segments (class 1)
# Sub_044:   57 segments (class 0)
# Sub_056:  120 segments (class 0)
# Sub_002:   64 segments (class 1)
# Sub_022:  109 segments (class 1)
# Sub_003:   57 segments (class 1)
# Sub_057:  120 segments (class 0)
# Sub_040:   65 segments (class 0)
# Sub_036:   69 segments (class 0)
# Sub_053:   71 segments (class 0)
# Sub_024:  105 segments (class 1)
# Sub_059:  110 segments (class 0)
# Sub_011:   84 segments (class 1)
# Sub_023:   96 segments (class 1)
# Sub_019:  124 segments (class 1)
# Sub_058:  105 segments (class 0)
# Sub_039:   72 segments (class 0)
# Sub_021:   94 segments (class 1)
# Sub_061:  114 segments (class 0)
# Sub_015:   90 segments (class 1)
# Sub_052:   87 segments (class 0)
# --> Shuffling Train segments randomly...
#
# Loading Test data:
# ────────────────────────────────────────────────────────────
# Sub_011:  154 segments (class 1)
# Sub_055:  164 segments (class 0)
# Sub_034:  194 segments (class 1)
# Sub_022:  164 segments (class 1)
# Sub_063:  161 segments (class 0)
# Sub_021:  184 segments (class 1)
# Sub_054:  168 segments (class 0)
# Sub_052:  152 segments (class 0)
# Sub_024:  153 segments (class 1)
# Sub_029:  148 segments (class 1)
# Sub_051:  157 segments (class 0)
# Sub_031:  231 segments (class 1)
# Sub_042:  195 segments (class 0)
# Sub_033:  141 segments (class 1)
# Sub_039:  171 segments (class 0)
# Sub_047:  161 segments (class 0)
# Sub_007:  153 segments (class 1)
# Sub_019:  184 segments (class 1)
# Sub_045:  172 segments (class 0)
# Sub_065:  176 segments (class 0)
# Sub_030:  111 segments (class 1)
# Sub_003:   61 segments (class 1)
# Sub_061:  161 segments (class 0)
# Sub_002:  158 segments (class 1)
# Sub_038:  178 segments (class 0)
# Sub_004:  141 segments (class 1)
# Sub_064:  169 segments (class 0)
# Sub_035:  151 segments (class 1)
# Sub_020:  173 segments (class 1)
# Sub_059:  157 segments (class 0)
# Sub_009:  122 segments (class 1)
# Sub_015:  182 segments (class 1)
# Sub_032:  170 segments (class 1)
# Sub_027:  166 segments (class 1)
# Sub_037:  155 segments (class 0)
# Sub_040:  203 segments (class 0)
# Sub_028:  165 segments (class 1)
# Sub_057:  159 segments (class 0)
# Sub_013:  168 segments (class 1)
# Sub_018:  169 segments (class 1)
# Sub_053:  159 segments (class 0)
# Sub_005:  160 segments (class 1)
# Sub_006:  127 segments (class 1)
# Sub_062:  182 segments (class 0)
# Sub_023:  172 segments (class 1)
# Sub_036:  170 segments (class 1)
# Sub_041:  177 segments (class 0)
# Sub_014:  189 segments (class 1)
# Sub_048:  202 segments (class 0)
# Sub_060:  150 segments (class 0)
# Sub_026:  183 segments (class 1)
# Sub_017:  169 segments (class 1)
# Sub_058:  152 segments (class 0)
# Sub_012:  179 segments (class 1)
# Sub_050:  165 segments (class 0)
# Sub_025:  139 segments (class 1)
# Sub_049:  156 segments (class 0)
# Sub_056:  177 segments (class 0)
# Sub_008:  159 segments (class 1)
# Sub_046:  151 segments (class 0)
# Sub_016:  197 segments (class 1)
# Sub_043:  165 segments (class 0)
# Sub_010:  258 segments (class 1)
# Sub_001:  119 segments (class 1)
# Sub_044:  176 segments (class 0)
# --> Shuffling Test segments randomly...
#
# Applying minmax normalization (per_sample)...
# Normalization applied successfully
#
# ================================================================================
# Data Preparation Complete for Fold 1
# ================================================================================
#   Train:       (5934, 19, 640)
#   Validation:  None
#   Test:        (10735, 19, 640)
# ================================================================================
#
#
# Dataset split:
#   Train: 5934 samples
#   Val:   None (val_split=0) samples
#   Test:  10735 samples
#
# Model: EEGModel | Device: cuda
# Total parameters: 490,114 | Trainable: 490,114
#
# Training without validation set (using all epochs)...
#
# ================================================================================
# << TRAINING STARTED >>
# ================================================================================
# Device: cuda | Train samples: 5,934
# Batch size: 16 | Effective batch size: 16
# Max epochs: 6 | Early stopping patience: None
# ================================================================================
#
# Epoch [  1/6] | Train Acc:  52.18% | LR: 1.00e-03
# Epoch [  2/6] | Train Acc:  54.92% | LR: 9.33e-04
# Epoch [  3/6] | Train Acc:  61.60% | LR: 7.50e-04
# Epoch [  4/6] | Train Acc:  70.15% | LR: 5.01e-04
# Epoch [  5/6] | Train Acc:  73.55% | LR: 2.51e-04
# Epoch [  6/6] | Train Acc:  75.76% | LR: 6.79e-05
#
# ================================================================================
# TRAINING COMPLETED | Best Val Acc: 0.00%
# ================================================================================
#
#
# === Subject-level Evaluation (65 subjects) ===
# ==================================================
# === Final Subject-Level Metrics ===
# ==================================================
# Evaluated Subjects: 65/65
# Accuracy:             0.8462
# Sensitivity (AD):    0.7778
# Specificity (HC):    0.9310
# Precision (AD):      0.9333
# F1-Score (AD):       0.8485
# ROC-AUC:             0.9128
# ==================================================
#
# ================================================================================
# Fold 1 Test Results
# ================================================================================
#   Accuracy:    0.8462 (84.62%)
#   Sensitivity: 0.7778 (77.78%)
#   Specificity: 0.9310 (93.10%)
#   ROC AUC:     0.9128
#   Precision:   0.9333
#   Recall:      0.7778
#   F1-Score:    0.8485
# ================================================================================
#
#
# ================================================================================
# Segment CSV Files ...
# ================================================================================
#  Fold 1: files saved successfully.
# ================================================================================
#
# Completed 1/1 folds
#
# Complete raw results object saved to: /teamspace/studios/this_studio/Phd/experiment/CrossBA/results/CrossBAGitHub/tables/raw_all_fold_results.pkl
#
# ================================================================================
# FINAL CROSS-VALIDATION RESULTS
# ================================================================================
#
# Performance Summary (Mean ± Std):
# --------------------------------------------------------------------------------
#   Accuracy       : 0.8462 ± nan [0.8462, 0.8462]
#   Roc Auc        : 0.9128 ± nan [0.9128, 0.9128]
#   Sensitivity    : 0.7778 ± nan [0.7778, 0.7778]
#   Specificity    : 0.9310 ± nan [0.9310, 0.9310]
#   Precision      : 0.9333 ± nan [0.9333, 0.9333]
#   Recall         : 0.7778 ± nan [0.7778, 0.7778]
#   F1 Score       : 0.8485 ± nan [0.8485, 0.8485]
#
# ================================================================================
# Individual Fold Results
# ================================================================================
#   Fold | Accuracy |       F1 |      AUC |     Sens |     Spec
# --------------------------------------------------------------------------------
#      1 |   0.8462 |   0.8485 |   0.9128 |   0.7778 |   0.9310
# ================================================================================
#
# Results saved to: /teamspace/studios/this_studio/Phd/experiment/CrossBA/results/CrossBAGitHub/tables/cv_results__1folds.csv
#
# 95% Confidence Intervals:
# --------------------------------------------------------------------------------
#   Accuracy       : 0.8462 [0.0000, 1.0000]
#   Roc Auc        : 0.9128 [0.0000, 1.0000]
#   Sensitivity    : 0.7778 [0.0000, 1.0000]
#   Specificity    : 0.9310 [0.0000, 1.0000]
#   Precision      : 0.9333 [0.0000, 1.0000]
#   Recall         : 0.7778 [0.0000, 1.0000]
#   F1 Score       : 0.8485 [0.0000, 1.0000]
# ================================================================================
# Confidence intervals saved to: /teamspace/studios/this_studio/Phd/experiment/CrossBA/results/CrossBAGitHub/tables/confidence_intervals.csv
#
# Full model config, parameters & best fold metrics successfully saved to: /teamspace/studios/this_studio/Phd/experiment/CrossBA/results/CrossBAGitHub/model_info.json
#
#  Subject-level voting proportions successfully saved to: /teamspace/studios/this_studio/Phd/experiment/CrossBA/results/CrossBAGitHub/tables/subject_level_voting_proportions.csv
#
# ================================================================================
# PIPELINE COMPLETED SUCCESSFULLY!
# ================================================================================
# Successful folds: 1/1
#
# ================================================================================
# Generating Plots From Saved Results: /teamspace/studios/this_studio/Phd/experiment/CrossBA/results/CrossBAGitHub/tables/raw_all_fold_results.pkl
# ================================================================================
# Training curves saved: /teamspace/studios/this_studio/Phd/experiment/CrossBA/results/CrossBAGitHub/plots/fold_1_training_curves.png
# Confusion matrix saved: /teamspace/studios/this_studio/Phd/experiment/CrossBA/results/CrossBAGitHub/plots/fold_1_confusion_matrix.png
#
# ================================================================================
# Cross-Validation Summary
# ================================================================================
#   Accuracy:     0.8462 ± 0.0000
#   AUC:          0.9128 ± 0.0000
#   Sensitivity:  0.7778 ± 0.0000
#   Specificity:  0.9310 ± 0.0000
#   F1-Score:     0.8485 ± 0.0000
# ================================================================================
#
# Mean confusion matrix saved: /teamspace/studios/this_studio/Phd/experiment/CrossBA/results/CrossBAGitHub/plots/mean_confusion_matrix.png
# ROC curve saved: /teamspace/studios/this_studio/Phd/experiment/CrossBA/results/CrossBAGitHub/plots/roc_publication.png
# Combined confusion matrices saved successfully: /teamspace/studios/this_studio/Phd/experiment/CrossBA/results/CrossBAGitHub/plots/combined_confusion_matrices.png
#
# All plots generated successfully and saved in: /teamspace/studios/this_studio/Phd/experiment/CrossBA/results/CrossBAGitHub/plots
#
# ================================================================================
# Generating Segment CSV Files for All Folds...
# ================================================================================
#
# ================================================================================
# Segment CSV Files ...
# ================================================================================
#  Fold 1: files saved successfully.
# ================================================================================
# ================================================================================
#
#  Subject-level voting proportions successfully saved to: /teamspace/studios/this_studio/Phd/experiment/CrossBA/results/CrossBAGitHub/tables/subject_level_voting_proportions.csv
# Stratified performance report saved successfully to: /teamspace/studios/this_studio/Phd/experiment/CrossBA/results/CrossBAGitHub/tables/report_performance_separately.csv
#
# Memory cleanup completed
